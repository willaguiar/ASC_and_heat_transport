# %% [markdown]
# # Plotting the Map of average sqrt(V2) for the RYF experiment under .1 resolution
#
# **Requirements:** The `conda/analysis3-22.07` (or later) module on the OOD or Gadi (or your own up-to-date cookbook installation).

# %%
# %matplotlib inline
# %config InlineBackend.figure_format='retina'

import matplotlib.pyplot as plt
import os
import xarray as xr
import numpy as np
import IPython.display
import cmocean as cm
import cartopy.crs as ccrs
import cosima_cookbook as cc
session = cc.database.create_session()

# %%
from dask.distributed import Client
#client = Client(n_workers=os.cpu_count()-2, threads_per_worker=1)
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:33309' processes=7 threads=28, memory=0.98 TiB>

# %%
#Loading isobaths
# Load the isobath information
iso_dir='/g/data/x77/wf4500/ASC_project/Post_process/'

data_650m = np.load(iso_dir + 'Antarctic_slope_contour_smoothed_u_t_650m_plt_approach.npz')
data_1000m = np.load(iso_dir + 'Antarctic_slope_contour_smoothed_u_t_1000m_plt_approach.npz')
data_1500m = np.load(iso_dir + 'Antarctic_slope_contour_smoothed_u_t_1500m_plt_approach.npz')
data_2000m = np.load(iso_dir + 'Antarctic_slope_contour_smoothed_u_t_2000m_plt_approach.npz')

# %%
vvars = cc.querying.get_variables(session, experiment='01deg_jra55v13_ryf9091')
vvars[vvars['name'].str.lower().str.contains('hu')]

#There is no dzu. SO I have to either regrid dzt into u, or find another way to do iit
#Ocean.nc contains monthly u,v, has each netcdf containing 3 months 
#of monthly data (nt=3). I want to get the last 20 yrs for a climatology. (Ideally would
# be 30, but I think that would crash). That means I need 20*4 = last 80 netcdfs
# Out:
#     name               long_name units frequency  \
# 422   hu  ocean depth on u-cells     m    static
#
#                              ncfile cell_methods  # ncfiles  \
# 422  output1115/ocean/ocean_grid.nc  time: point       1164
#
#               time_start             time_end
# 422  1900-04-01 00:00:00  2180-01-01 00:00:00

# %%
#Getting variables
#variable = 'uvel'
experiment = '01deg_jra55v13_ryf9091'
UVEL = cc.querying.getvar(experiment, 'u' , session, frequency='1 monthly', n=-40)
UVEL = UVEL.isel({'yu_ocean': slice(0, 494)}).isel({'st_ocean': slice(0, 40)})# First 500 m
VVEL = cc.querying.getvar(experiment, 'v' , session, frequency='1 monthly',n=-40)
VVEL = VVEL.isel({'yu_ocean': slice(0, 494)}).isel({'st_ocean': slice(0, 40)})
dzt = cc.querying.getvar(experiment, 'dzt' , session, frequency='1 monthly',n=-40)
dzt = dzt.isel({'yt_ocean': slice(0, 494)}).isel({'st_ocean': slice(0, 40)})
# To minimize computational efforts you can....
      # Set ylim to get only the Southermost Latitudes of the Southern Ocean (Lets say south of 60S)
      # Set a depth limit too.. perhaps 1000m or 500 m
      #When I calculate the mean it has to be a weighted mean against dzt

# %%
#Load the bathymetry
hu = cc.querying.getvar(experiment, 'hu', session, n=1).drop(['geolat_c', 'geolon_c']).isel({'yu_ocean': slice(0, 494)})

# %%
# Calculating Mean V and U along time
VVELmean = VVEL.mean('time')
UVELmean = UVEL.mean('time')
dztmean = dzt.mean('time')

# %%
# VVEL time
VVELtime = VVEL.isel(time=slice(0,12,1))
UVELtime = UVEL.isel(time=slice(0,12,1))
dzttime = dzt.isel(time=slice(0,12,1))

# %%
import xgcm
print("xgcm version ", xgcm.__version__)
folder = '/g/data/ik11/outputs/access-om2-01/01deg_jra55v13_ryf9091/output000/ocean/'
grid = xr.open_mfdataset(folder+'ocean_grid.nc', combine='by_coords').isel({'yu_ocean': slice(0, 494)}).isel({'yt_ocean': slice(0, 494)})

ds = xr.merge([UVELmean,VVELmean,dztmean, grid])
ds.coords['xt_ocean'].attrs.update(axis='X')
ds.coords['xu_ocean'].attrs.update(axis='X', c_grid_axis_shift=0.5)
ds.coords['yt_ocean'].attrs.update(axis='Y')
ds.coords['yu_ocean'].attrs.update(axis='Y', c_grid_axis_shift=0.5)

grid = xgcm.Grid(ds, periodic=['X','Y'])
ds
# Out:
# xgcm version  0.8.1
# <xarray.Dataset>
# Dimensions:     (st_ocean: 40, xu_ocean: 3600, yu_ocean: 494, xt_ocean: 3600,
#                  yt_ocean: 494, time: 1)
# Coordinates:
#   * st_ocean    (st_ocean) float64 0.5413 1.681 2.94 4.332 ... 423.7 468.4 517.6
#   * xu_ocean    (xu_ocean) float64 -279.9 -279.8 -279.7 ... 79.8 79.9 80.0
#   * yu_ocean    (yu_ocean) float64 -81.09 -81.05 -81.0 ... -59.92 -59.87 -59.82
#   * xt_ocean    (xt_ocean) float64 -279.9 -279.8 -279.7 ... 79.75 79.85 79.95
#   * yt_ocean    (yt_ocean) float64 -81.11 -81.07 -81.02 ... -59.95 -59.9 -59.85
#   * time        (time) object 1900-04-01 00:00:00
#     geolon_t    (yt_ocean, xt_ocean) float32 dask.array<chunksize=(494, 3600), meta=np.ndarray>
#     geolat_t    (yt_ocean, xt_ocean) float32 dask.array<chunksize=(494, 3600), meta=np.ndarray>
#     geolon_c    (yu_ocean, xu_ocean) float32 dask.array<chunksize=(494, 3600), meta=np.ndarray>
# ...

# %%
# %%time

UVELmeanz = ((grid.interp(UVELmean,['X','Y'])*dztmean).sum('st_ocean'))/dztmean.sum('st_ocean')
VVELmeanz = ((grid.interp(VVELmean,['X','Y'])*dztmean).sum('st_ocean'))/dztmean.sum('st_ocean')



#along time
n=0
Ui=UVELtime.isel(time=n)
Vi=VVELtime.isel(time=n)
dzti=dzttime.isel(time=n)
UVELtimemeanz = ((grid.interp(Ui,['X','Y'])*dzti).sum('st_ocean'))/dzti.sum('st_ocean')
VVELtimemeanz = ((grid.interp(Vi,['X','Y'])*dzti).sum('st_ocean'))/dzti.sum('st_ocean')


for n in range(1,12):
    Ui=UVELtime.isel(time=n)
    Vi=VVELtime.isel(time=n)
    dzti=dzttime.isel(time=n)
    # UVELtimemeanz = ((grid.interp(Ui,['X','Y'])*dzti).sum('st_ocean'))/dzti.sum('st_ocean')
    # VVELtimemeanz = ((grid.interp(Vi,['X','Y'])*dzti).sum('st_ocean'))/dzti.sum('st_ocean')
    UVELtimemeanz = xr.concat((UVELtimemeanz,((grid.interp(Ui,['X','Y'])*dzti).sum('st_ocean'))/dzti.sum('st_ocean')),dim='Time')
    VVELtimemeanz = xr.concat((VVELtimemeanz,((grid.interp(Vi,['X','Y'])*dzti).sum('st_ocean'))/dzti.sum('st_ocean')),dim='Time')
# Out:
# CPU times: user 1.85 s, sys: 68.5 ms, total: 1.92 s
# Wall time: 1.82 s

# %%
# %%time
#Calculating the masks of negative U to apply to the speed, so eastward speeds are marked as 0, and westward speeds positive or reased
Umean_dir=UVELmeanz.where(UVELmeanz<0,1).where(UVELmeanz>0,-1)

Utime_dir=UVELtimemeanz.where(UVELtimemeanz<0,1).where(UVELtimemeanz>0,-1)
#Utime_dir.isel(Time=0).plot()
# Out:
# CPU times: user 22.4 ms, sys: 973 µs, total: 23.4 ms
# Wall time: 20.1 ms

# %%
# %%time
# Calculating the speed. NOTICE, HERE I AM TRYING TO MAKE A V SPEED CONSTRUCTION THAT MAINTAINS THE SIGN OF THE U, TO IDENTIFY ASC
V = np.multiply(np.sqrt(np.square(UVELmeanz) + np.square(VVELmeanz)),Umean_dir).compute()
Vtime = np.multiply(np.sqrt(np.square(UVELtimemeanz) + np.square(VVELtimemeanz)),Utime_dir).compute()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.01/lib/python3.9/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.01/lib/python3.9/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.01/lib/python3.9/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-23.01/lib/python3.9/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# ...

# %% [markdown]
# ## Plotting stereographic map of V

# %%
projection = ccrs.SouthPolarStereo()

import matplotlib.path as mpath
import cartopy.feature as cft

land_50m = cft.NaturalEarthFeature('physical', 'land', '50m',
                                   edgecolor='black', facecolor='papayawhip', linewidth=0.5)

plt.figure(figsize=(6, 5))
ax = plt.axes(projection=projection)

ax.set_extent([-280, 80, -80, -60], crs=ccrs.PlateCarree())
ax.add_feature(land_50m, color=[0.8, 0.8, 0.8])
ax.coastlines(resolution='50m')
ax.gridlines(draw_labels=True,ylocs=[-65,-60],xlocs=[125,115])

theta = np.linspace(0, 2*np.pi, 100)
center, radius = [0.5, 0.5], 0.5
verts = np.vstack([np.sin(theta), np.cos(theta)]).T
circle = mpath.Path(verts * radius + center)
ax.set_boundary(circle, transform=ax.transAxes)

V.plot(x='xt_ocean', y='yt_ocean',
         transform=ccrs.PlateCarree(),
         vmin=-.07, vmax=.07, extend='both',
         cmap=cm.cm.curl,
         cbar_kwargs = {'label': '|V|',
                        'fraction': 0.03,
                        'aspect': 15,
                        'shrink': 0.7});

# %% [markdown]
# Gathering the different contours

# %%
# We are interested in the u-grid:

#for 650m
num_point_650m  = data_650m['num_points_u']
distance_along_contour_650m = data_650m['distance_along_contour_u']
lon_along_contour_650m = data_650m['lon_along_contour_u']
lat_along_contour_650m = data_650m['lat_along_contour_u']


#for 1000m
num_point_1000m  = data_1000m['num_points_u']
distance_along_contour_1000m = data_1000m['distance_along_contour_u']
lon_along_contour_1000m = data_1000m['lon_along_contour_u']
lat_along_contour_1000m = data_1000m['lat_along_contour_u']



#for 1500m
num_point_1500m  = data_1500m['num_points_u']
distance_along_contour_1000m = data_1500m['distance_along_contour_u']
lon_along_contour_1500m = data_1500m['lon_along_contour_u']
lat_along_contour_1500m = data_1500m['lat_along_contour_u']


#for 2000m
num_point_2000m  = data_2000m['num_points_u']
distance_along_contour_2000m = data_2000m['distance_along_contour_u']
lon_along_contour_2000m = data_2000m['lon_along_contour_u']
lat_along_contour_2000m = data_2000m['lat_along_contour_u']

# %% [markdown]
# Checking different isobathson the ASC contour

# %%
plt.figure(figsize=(12, 5))
V.plot(vmin=-.1, vmax=.1, extend='both',cmap=cm.cm.curl)
plt.plot(lon_along_contour_2000m[:-1],lat_along_contour_2000m[:-1],'r-',label='2000m')
plt.plot(lon_along_contour_1500m[:-1],lat_along_contour_1500m[:-1],color="tab:blue",label='1500m')
plt.plot(lon_along_contour_1000m[:-1],lat_along_contour_1000m[:-1],'y-',label='1000m')
plt.xlim(-20,80)
plt.ylim(-72,-65)
plt.title('[20W 80E]')
plt.legend(fontsize=13,loc='lower right')

# %% [markdown]
# Within [-20, 80] it seems that 2000m might be a little too deep, except on  the little ~40E. In turn, the 6650m, and 1000m isobaths seem to go too much south of the ASC centre. (Perhaps a 1500m-ish?)

# %%
plt.figure(figsize=(12, 5))
V.plot(vmin=-0.05, vmax=.05, extend='both',cmap=cm.cm.curl)
plt.plot(lon_along_contour_2000m[:-1],lat_along_contour_2000m[:-1],'r-',label='2000m')
plt.plot(lon_along_contour_1500m[:-1],lat_along_contour_1500m[:-1],color="tab:blue",label='1500m')
plt.plot(lon_along_contour_1000m[:-1],lat_along_contour_1000m[:-1],'y-',label='1000m')
plt.xlim(-65,-20)
plt.ylim(-75,-70)
plt.title('[60W 20W], Inner Weddell')
plt.legend(fontsize=13,loc='upper right')

# %% [markdown]
# In the inner Weddell Sea the 1000m isobath seems to do a slightly better job (except East of 25W, where the 2000m isobath looks better).

# %%
plt.figure(figsize=(7, 12))
V.plot(vmin=-0.09, vmax=.09, extend='both',cmap=cm.cm.curl)
plt.plot(lon_along_contour_2000m[:-1],lat_along_contour_2000m[:-1],'r-',label='2000m')
plt.plot(lon_along_contour_1500m[:-1],lat_along_contour_1500m[:-1],color="tab:blue",label='1500m')
plt.plot(lon_along_contour_1000m[:-1],lat_along_contour_1000m[:-1],'y-',label='1000m')
plt.xlim(-65,-49)
plt.ylim(-72.5,-60)
plt.title('[65W 49W], East Antarcric Peninsula')
plt.legend(fontsize=13,loc='lower left')

# %% [markdown]
# East Antarctic Peninsula...Around 1500m ?

# %%
plt.figure(figsize=(12, 7))
V.plot(vmin=-0.09, vmax=.09, extend='both',cmap=cm.cm.curl)
plt.plot(lon_along_contour_2000m[:-1],lat_along_contour_2000m[:-1],'r-',label='2000m')
plt.plot(lon_along_contour_1500m[:-1],lat_along_contour_1500m[:-1],color="tab:blue",label='1500m')
plt.plot(lon_along_contour_1000m[:-1],lat_along_contour_1000m[:-1],'y-',label='1000m')
plt.xlim(-280,-180)
plt.ylim(-78,-62)
plt.title('[65W 49W], West Ross Sea')
plt.legend(fontsize=13,loc='lower left')

# %% [markdown]
# Seems like each place will have a different isobath that better matches the ASC. Maybe we can make a composite line, using different isobath in each sector

# %%
Vtosave=xr.Dataset({'VVEL': (('xt_ocean', 'yt_ocean'), np.array(V))})
Vtosave.to_netcdf('/g/data/x77/wf4500/ASC_project/Post_process/ClimatologyV.nc')

# %% [markdown]
# ## Regional check up

# %%
UVELmeanz2 = UVELmeanz.sel({'xt_ocean': slice(-246, -237)}).mean('xt_ocean').compute()
UVELmeanz2 = UVELmeanz2.compute()
humean=hu.sel({'xu_ocean': slice(-246, -237)}).mean('xu_ocean').compute()
# Out:
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.10/lib/python3.9/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.10/lib/python3.9/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.10/lib/python3.9/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))
# /g/data/hh5/public/apps/miniconda3/envs/analysis3-22.10/lib/python3.9/site-packages/dask/core.py:119: RuntimeWarning: invalid value encountered in divide
#   return func(*(_execute_task(a, cache) for a in args))

# %%
projection = ccrs.Mercator(central_longitude=120, min_latitude=-80.0, max_latitude=-55)

plt.figure(figsize=(10, 5))
ax = plt.axes(projection=projection)

ax.set_extent([110, 130, -70, -60], crs=ccrs.PlateCarree())
ax.add_feature(land_50m, color=[0.8, 0.8, 0.8])
ax.coastlines(resolution='10m')
ax.gridlines(draw_labels=True,ylocs=[-65],xlocs=[123,114])
V.plot(x='xt_ocean', y='yt_ocean',
         transform=ccrs.PlateCarree(),
         vmin=0, vmax=.05, extend='both',
         cmap=cm.cm.speed,
         cbar_kwargs = {'label': '|V|',
                        'fraction': 0.03,
                        'aspect': 15,
                        'shrink': 0.7});
plt.title('Totten Ice Shelf')
# Out:
# Text(0.5, 1.0, 'Totten Ice Shelf')

# %%
humean.isel(yu_ocean=370)
#By looking at the location od the 1000m bathymetry, it seems to me that ASC is mostly enclosed between [65.4S 64.7S]. 
#So I will just use the value of U at the 100m bathymetry location.
# Out:
# <xarray.DataArray 'hu' ()>
# array(947.2298, dtype=float32)
# Coordinates:
#     yu_ocean  float64 -65.46

# %%
#maximum negative speed seem to be ~67S. but South of 64S, all zonal speed seems negative (ASC)

fig, ax1 = plt.subplots()
#ax2 = ax1.twinx()
#Batrhymetry
ax1.plot(UVELmeanz2['yt_ocean'], UVELmeanz2, 'b-')
ax1.plot(UVELmeanz2['yt_ocean'].sel(yt_ocean=-65.46, method='nearest'), UVELmeanz2.sel(yt_ocean=-65.46, method='nearest'), 'k*')
ax1.set_xlabel('Latitude')
ax1.grid()
#Uvel
#ax2.plot(UVELmeanz2['yt_ocean'],UVELmeanz2, 'g-')
#ax2.grid()


ax1.set_ylabel('Bathymetry [m]', color='b')
plt.title('Totten Ice Shelf')
# Out:
# Text(0.5, 1.0, 'Totten Ice Shelf')

# %%
projection = ccrs.Mercator(central_longitude=72, min_latitude=-80.0, max_latitude=-55)

plt.figure(figsize=(10, 5))
ax = plt.axes(projection=projection)

ax.set_extent([80, 68, -73, -65], crs=ccrs.PlateCarree())
ax.add_feature(land_50m, color=[0.8, 0.8, 0.8])
ax.coastlines(resolution='10m')
ax.gridlines(draw_labels=True,ylocs=[-65],xlocs=[123,114])
V.plot(x='xt_ocean', y='yt_ocean',
         transform=ccrs.PlateCarree(),
         vmin=0, vmax=.05, extend='both',
         cmap=cm.cm.speed,
         cbar_kwargs = {'label': '|V|',
                        'fraction': 0.03,
                        'aspect': 15,
                        'shrink': 0.7});
plt.title('Amery Ice Shelf')
# Out:
# Text(0.5, 1.0, 'Amery Ice Shelf')

# %%
UVELmeanza = UVELmeanz.sel({'xt_ocean': slice(68, 80)}).mean('xt_ocean').compute()
UVELmeanza = UVELmeanza.compute()
humeana=hu.sel({'xu_ocean': slice(68, 80)}).mean('xu_ocean').compute()
UVELmeanza
# Out:
# <xarray.DataArray (yt_ocean: 494)>
# array([        nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
#                nan,         nan,         nan,         nan,         nan,
# ...

# %%
humeana.isel(yu_ocean=339)
# Out:
# <xarray.DataArray 'hu' ()>
# array(1028.2766, dtype=float32)
# Coordinates:
#     yu_ocean  float64 -66.77

# %%
#maximum negative speed seem to be ~67S. but South of 64S, all zonal speed seems negative (ASC)

fig, ax1 = plt.subplots()
#ax2 = ax1.twinx()
#Batrhymetry
ax1.plot(UVELmeanza['yt_ocean'], UVELmeanza, 'b-')
ax1.plot(UVELmeanza['yt_ocean'].sel(yt_ocean=-66.77, method='nearest'), UVELmeanza.sel(yt_ocean=-66.77, method='nearest'), 'k*')
ax1.set_xlabel('Latitude')
ax1.grid()



ax1.set_ylabel('Bathymetry [m]', color='b')
plt.title('Amery Ice Shelf')
# Out:
# Text(0.5, 1.0, 'Amery Ice Shelf')

# %% [markdown]
# ## Output checking

# %%
# %matplotlib inline

import cosima_cookbook as cc
import matplotlib.pyplot as plt
import numpy as np
import netCDF4 as nc
import cartopy.crs as ccrs
import matplotlib.path as mpath
import xarray as xr
import cmocean.cm as cm
import matplotlib.cm as cm
from collections import OrderedDict
import glob,os
import matplotlib.colors as col
from datetime import timedelta

import logging
logging.captureWarnings(True)
logging.getLogger('py.warnings').setLevel(logging.ERROR)
logging.getLogger('distributed.utils_perf').setLevel(logging.ERROR)

from dask.distributed import Client

client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:38043' processes=7 threads=28, memory=251.20 GiB>

# %%
#Importing panan0025
dirbase='/home/156/wf4500/v45_wf4500/panan0025/panana0025_ryf_26052023/mom6-panan/archive/'
p0025_daily=xr.open_dataset(dirbase+'output108/20000101.ocean_month_z.nc')
p0025_daily
# Out:
# <xarray.Dataset>
# Dimensions:     (xh: 14400, yh: 3383, z_l: 75, z_i: 76, time: 1, nv: 2,
#                  xq: 14401, yq: 3384)
# Coordinates:
#   * xh          (xh) float64 -280.0 -280.0 -279.9 -279.9 ... 79.94 79.96 79.99
#   * yh          (yh) float64 -81.09 -81.08 -81.07 ... -37.03 -37.01 -36.99
#   * z_l         (z_l) float64 0.5413 1.681 2.94 ... 5.511e+03 5.709e+03
#   * z_i         (z_i) float64 0.0 1.083 2.279 ... 5.412e+03 5.61e+03 5.809e+03
#   * time        (time) object 2000-01-16 12:00:00
#   * nv          (nv) float64 1.0 2.0
#   * xq          (xq) float64 -280.0 -280.0 -279.9 -279.9 ... 79.95 79.97 80.0
#   * yq          (yq) float64 -81.1 -81.09 -81.08 -81.07 ... -37.02 -37.0 -36.98
# Data variables: (12/14)
#     volcello    (time, z_l, yh, xh) float32 ...
#     uo          (time, z_l, yh, xq) float32 ...
#     vo          (time, z_l, yq, xh) float32 ...
#     thetao      (time, z_l, yh, xh) float32 ...
#     so          (time, z_l, yh, xh) float32 ...
#     rhopot2     (time, z_l, yh, xh) float32 ...
#     ...          ...
#     T_adx       (time, z_l, yh, xq) float32 ...
#     T_ady       (time, z_l, yq, xh) float32 ...
#     average_T1  (time) datetime64[ns] ...
#     average_T2  (time) datetime64[ns] ...
#     average_DT  (time) timedelta64[ns] ...
#     time_bnds   (time, nv) timedelta64[ns] ...
# Attributes:
#     title:             panan
#     associated_files:  areacello: 20000101.ocean_static.nc
#     grid_type:         regular
#     grid_tile:         N/A
#     history:           20230823T1716Z: /g/data/ik11/inputs/mom6/panan/0025deg...

# %%
p0025_daily.T_ady.isel(z_l=0,time=0).plot()

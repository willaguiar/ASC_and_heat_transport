# %%
import xarray as xr
from dask.distributed import Client
import numpy as np
client = Client()
client
# Out:
# <Client: 'tcp://127.0.0.1:39069' processes=7 threads=28, memory=251.19 GiB>

# %%
figdir = '/g/data/e14/txs156/Analysis/ACCESS-OM2/Clustering/ASC_and_heat_transport/Figures/'

# %%
u_along = xr.open_mfdataset('/g/data/x77/wf4500/ASC_project/ASC_z_daily_10deg/OM2_01_iaf_cycle3/*')

# %%
# %%time
import intake

cat = intake.cat.access_nri
iaf_run = '01deg_jra55v140_iaf_cycle3'


dzt = cat[iaf_run].search(variable=['dzt'])
# Out:
# CPU times: user 3.81 s, sys: 380 ms, total: 4.19 s
# Wall time: 3.04 s

# %%
dzt = cat[iaf_run].search(variable=['dzt']).to_dask(    
    xarray_open_kwargs={
        "chunks" : "auto",
    })

# %%
thickness = dzt.mean(dim=['time','yt_ocean', 'xt_ocean']).dzt.load()
depths = np.linspace(0,6000, 61)
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.09/lib/python3.11/site-packages/intake_esm/core.py:321: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   records = grouped.get_group(internal_key).to_dict(orient='records')

# %%
i=3
u_along_mean = u_along.U.sel(st_ocean=slice(None,depths[i])).weighted(thickness).mean('st_ocean')
u_along_mean_annual = u_along_mean.groupby('time.year').mean('time')

# %%
u_along_mean_annual.plot()

# %%
CSHT_layerwise_CDW()
linregess
# Out:
# <xarray.Dataset> Size: 481MB
# Dimensions:   (time: 22265, st_ocean: 75, lon_bins: 36)
# Coordinates:
#   * st_ocean  (st_ocean) float64 600B 0.5413 1.681 2.94 ... 5.511e+03 5.709e+03
#   * time      (time) datetime64[ns] 178kB 1958-01-01T12:00:00 ... 2018-12-31T...
#   * lon_bins  (lon_bins) float64 288B -273.5 -263.5 -253.5 ... 56.5 66.5 76.5
# Data variables:
#     U         (time, st_ocean, lon_bins) float64 481MB dask.array<chunksize=(31, 75, 36), meta=np.ndarray>

# %%
Holvmoller(lon_bin, depth)

# %%
u_along_avg_surface.groupby('time.year').mean('time')
# Out:
# INFO:flox:Entering _validate_reindex: reindex is None
# INFO:flox:Leaving _validate_reindex: method = None, returning None
# INFO:flox:_choose_engine: Choosing 'flox'
# INFO:flox:find_group_cohorts: cohorts is preferred, chunking is perfect.
# INFO:flox:_choose_method: method is None
# INFO:flox:_choose_method: choosing preferred_method=cohorts
# INFO:flox:Entering _validate_reindex: reindex is None
# INFO:flox:Leaving _validate_reindex: reindex is False
# <xarray.DataArray (year: 61, contour_index: 6002)> Size: 3MB
# dask.array<transpose, shape=(61, 6002), dtype=float64, chunksize=(1, 6002), chunktype=numpy.ndarray>
# Coordinates:
#   * contour_index  (contour_index) int64 48kB 1 2 3 4 5 ... 5999 6000 6001 6002
#   * year           (year) int64 488B 1958 1959 1960 1961 ... 2015 2016 2017 2018

# %% [markdown]
# ## Composites

# %%
import intake
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import netCDF4 as nc
import cartopy.crs as ccrs
import cartopy.feature as cfeature
import xarray as xr
import cmocean.cm as cmocean
import glob
import matplotlib.path as mpath
import matplotlib.colors as col
import pandas as pd
import scipy.stats as stats
from tqdm import tqdm
import logging
import matplotlib.cm as cm
from dask.distributed import Client
import matplotlib.colors as col
import matplotlib.gridspec as gs
from matplotlib.collections import LineCollection
from matplotlib.colors import Normalize


from cartopy.mpl.ticker import LongitudeFormatter, LatitudeFormatter

logging.captureWarnings(True)
logging.getLogger('py.warnings').setLevel(logging.ERROR)

figdir = '/g/data/e14/txs156/Analysis/ACCESS-OM2/Clustering/ASC_and_heat_transport/Figures/'

# %%
client = Client(threads_per_worker=1)

# %%
#in this definition, no frequency can be used only for static data
catalog = intake.cat.access_nri
#defining importing function
def importer(experiment,catalog,variable, frequency = 'fx',start_time=0,end_time=0,chunks=''):
    xarray_open_kwargs = {"chunks": chunks,'decode_timedelta':True}
    if variable == 'volcello' and experiment == 'panant-01-zstar-ACCESSyr2':
        file_id='ocean.1mon.nv:2.xh:3600.xq:3601.yh:845.yq:846.z_i:76.z_l:75'
        var = catalog[experiment].search(variable=variable, frequency = frequency,file_id = file_id).to_dask(xarray_open_kwargs=xarray_open_kwargs)
    elif experiment == 'panant-005-zstar-ACCESSyr2' and (variable == 'volcello' or variable == 'T_adx' or variable == 'T_ady' or variable=='thetao'):
        file_id='ocean.1mon.nv:2.xh:7200.xq:7201.yh:1690.yq:1691.z_i:76.z_l:75'
        var = catalog[experiment].search(variable=variable, frequency = frequency,file_id = file_id).to_dask(xarray_open_kwargs=xarray_open_kwargs)
    elif experiment == 'panant-0025-zstar-ACCESSyr2' and (variable == 'volcello' or variable == 'T_adx' or variable == 'T_ady' or variable=='thetao'):
        file_id='ocean.1mon.nv:2.xh:14400.xq:14401.yh:3383.yq:3384.z_i:76.z_l:75'
        var = catalog[experiment].search(variable=variable, frequency = frequency,file_id = file_id).to_dask(xarray_open_kwargs=xarray_open_kwargs)
    elif frequency == 'fx': 
        var = catalog[experiment].search(variable=variable, frequency = frequency).to_dask(xarray_open_kwargs={'decode_timedelta':True})
    else:
        var = catalog[experiment].search(variable=variable, frequency = frequency).to_dask(xarray_open_kwargs=xarray_open_kwargs)
    if start_time!=0:
        time_slice='slice(start_time,end_time)'
        return eval("var." + variable + ".sel(time=" + time_slice + ")")
    elif start_time ==0:
        return eval("var." + variable)

# defining list variables function
def intakelist(catalog,experiment):
    return catalog[experiment].unique().variable

# %%
exp = '01deg_jra55v140_iaf_cycle3'
start_time= '1958-01-01'
end_time= '2018-12-31'
lat_range = slice(-90,-59)
isobath_depth = 1000
ht = importer(exp,catalog,'ht', frequency = 'fx')

# %%
# Load the along-slope velocity field for annual time series
u_along = xr.open_mfdataset('/g/data/ik11/users/wf4500/ASC_project_files/ASC_10deg_bin.nc')

# resample monthly:
u_along_da_months = u_along.resample(time='1M').mean()
u_along_da_months = u_along_da_months.sel(potrho0=slice(13.8,28.42))
u_along_da_months.load();

####################

# load monthly water mass mask:
age_mask_monthly = xr.open_mfdataset('/g/data/v45/wf4500/ASC_project_files/**_age_mask.nc')
age_mask = age_mask_monthly 
# select out CDW layer:
u_along_da_months_binned_CDW = (age_mask_monthly.CDW_mask*u_along_da_months)

####################

# get volume for averaging across density layers:
vol_bins = xr.open_mfdataset('/g/data/v45/wf4500/ASC_project_files/Volume_rho_10deg_bins.nc')
'''
CORRECTED FROM https://github.com/willaguiar/ASC_and_heat_transport/issues/47#issuecomment-2875013080
# do volume-weighted density average and annual averaging:
def vol_ave_potrho0_potmask(quantity,vol_bins):
    return (quantity * vol_bins.volume).mean('potrho0')/vol_bins.mean('potrho0').volume
'''
def vol_ave_potrho0_potmask(mask, quantity,vol_bins):
    return (mask * quantity * vol_bins.volume).mean('potrho0')/(mask*vol_bins.volume).mean('potrho0')

U_along_annual_binned_CDW_volav = vol_ave_potrho0_potmask(age_mask_monthly.CDW_mask, u_along_da_months_binned_CDW,vol_bins).groupby('time.year').mean('time')
U_along_annual_binned_CDW_volav = U_along_annual_binned_CDW_volav.load()
# climatological averaging and sum over layers:
U_along_clima_binned_CDW_volav = vol_ave_potrho0_potmask(age_mask_monthly.CDW_mask,u_along_da_months_binned_CDW,vol_bins).groupby('time.month').mean('time')
U_along_clima_binned_CDW_volav = U_along_clima_binned_CDW_volav.load()

# %%
def vol_ave_potrho0_potmask_f3(quantity,vol_bins):
    return (quantity * vol_bins.volume).mean('potrho0')/vol_bins.mean('potrho0').volume
U_along_annual_binned_CDW_volav_f3 = vol_ave_potrho0_potmask_f3(u_along_da_months_binned_CDW,vol_bins).groupby('time.year').mean('time')
U_along_annual_binned_CDW_volav_f3 = U_along_annual_binned_CDW_volav_f3.load()

# %%
vol_bins_monthly=vol_bins.copy()

# %%
# Load the along-slope velocity field, seasonal climatology using daily data
# NEED THIS AS TIME SERIES NOT CLIMATOLOGY:
u_along = xr.open_mfdataset('/g/data/x77/wf4500/ASC_project/ASC_sigma_daily_10deg/OM2_01_iaf_cycle3/U_daily_10deg_****-**.nc')
####################

# load daily climatology water mass mask:
age_mask_daily = xr.open_mfdataset('/g/data/x77/wf4500/ASC_project/age_mask_daily/OM2_01_iaf_cycle3/CDW_****-**.nc')

# select out CDW layer:
u_along_clima_binned_CDW = (age_mask_daily.CDW_mask*u_along)

####################

# get volume for averaging across density layers:
# NEED THIS AS TIME SERIES NOT CLIMATOLOGY:
vol_bins = xr.open_mfdataset('/g/data/x77/wf4500/ASC_project/volume_daily_10deg/OM2_01_iaf_cycle3/VOL*.nc')
# do volume-weighted density average:
# Corrected as in cell above
def vol_ave_potrho0_potmask(mask, quantity,vol_bins):
    return (mask * quantity * vol_bins.Volume).mean('potrho0')/(mask*vol_bins.Volume).mean('potrho0')

U_along_clima_binned_CDW_volav = vol_ave_potrho0_potmask(age_mask_daily.CDW_mask, u_along_clima_binned_CDW,vol_bins)

# compute seasonal climatology:
U_along_clima_binned_CDW_volav = U_along_clima_binned_CDW_volav.groupby('time.dayofyear').mean('time')

U_along_clima_binned_CDW_volav = U_along_clima_binned_CDW_volav.load()

# %%
age_mask_daily_DSW = xr.open_mfdataset('/g/data/x77/wf4500/ASC_project/age_mask_daily/OM2_01_iaf_cycle3/DSW_****-**.nc')
u_along_clima_binned_DSW = (age_mask_daily_DSW.DSW_mask*u_along)
U_along_clima_binned_DSW_volav = vol_ave_potrho0_potmask(age_mask_daily_DSW.DSW_mask, u_along_clima_binned_DSW,vol_bins)

# compute seasonal climatology:
U_along_clima_binned_DSW_volav = U_along_clima_binned_DSW_volav.groupby('time.dayofyear').mean('time')

U_along_clima_binned_DSW_volav = U_along_clima_binned_DSW_volav.load()

# %%
u_along_da_months_binned_DSW = (age_mask_monthly.DSW_mask*u_along_da_months)
#u_along_da_months_binned_DSW = u_along_clima_binned_DSW.resample(time='1M').mean()
u_along_da_months_binned_DSW['time']=age_mask_monthly.time
# vol_bins_monthlyforDSW= vol_bins.resample(time='1M').mean()
# vol_bins_monthlyforDSW['time']=age_mask_monthly.time
U_along_annual_binned_DSW_volav = vol_ave_potrho0_potmask(age_mask_monthly.DSW_mask, u_along_da_months_binned_DSW,vol_bins_monthly.rename({'volume':'Volume'})).groupby('time.year').mean('time')
U_along_annual_binned_DSW_volav = U_along_annual_binned_DSW_volav.load()
# Out:
# /g/data/xp65/public/apps/med_conda/envs/analysis3-25.11/lib/python3.11/site-packages/dask/_task_spec.py:759: RuntimeWarning: invalid value encountered in divide
#   return self.func(*new_argspec)

# %%
#vertical mean U
u_along_watercolumn = u_along.U.weighted(vol_bins.Volume.fillna(0)).mean('potrho0')
u_along_surf = u_along.U.bfill('potrho0').isel(potrho0=0)
u_along_watercolumn_clima = u_along_watercolumn.groupby('time.dayofyear').mean('time')
u_along_watercolumn_clima = u_along_watercolumn_clima.load()
u_along_surf_clima = u_along_surf.groupby('time.dayofyear').mean('time')
u_along_surf_clima = u_along_surf_clima.load()

# %%
#vertical mean U
u_along_watercolumn_annual = u_along_watercolumn.resample(time='1Y').mean()
u_along_watercolumn_annual = u_along_watercolumn_annual.load()
u_along_surf_annual = u_along_surf.resample(time='1Y').mean()
u_along_surf_annual = u_along_surf_annual.load()

# %%
# Load CSHT field annual
#CSHT_along = xr.open_mfdataset('/g/data/hh5/tmp/access-om/fbd581/ASC_project/Lon_binning/CSHT_ZC_potrho0_10degBins.nc')
CSHT_along = xr.open_mfdataset('/g/data/e14/fbd581/ASC_project/Lon_binning/CSHT_ZC_potrho0_10degBins.nc')
# resample monthly:
CSHT_along_monthly = CSHT_along.resample(time='1M').mean()

# apply age mask to select out CDW layer:
CSHT_months_binned_CDW = (age_mask_monthly.CDW_mask * CSHT_along_monthly )

# annual averaging and sum over layers:
CSHT_annual_binned_CDW = CSHT_months_binned_CDW.groupby('time.year').mean('time').sum(dim = 'potrho0')

# %%
# climatological averaging:
CSHT_along_daily = CSHT_along

# apply age mask to select out CDW layer:
CSHT_months_binned_CDW = (age_mask_daily.CDW_mask * CSHT_along_daily )

# sum over layers:
CSHT_clima_binned_CDW = CSHT_months_binned_CDW.sum(dim = 'potrho0')

# compute seasonal climatology:
CSHT_clima_binned_CDW = CSHT_clima_binned_CDW.groupby('time.dayofyear').mean('time')
CSHT_clima_binned_CDW = CSHT_clima_binned_CDW.load()

# %%
files_path = '/g/data/ik11/users/wf4500/ASC_project_files/'
file_extension = 'agemaskCDW_volav_corr'

ds = xr.open_dataset(files_path + 'r_sq_annual_10degBins_' + file_extension + '.nc')
r_sq_annual_10deg = ds.r_sq_annual
ds.close()

high_corr_lons = r_sq_annual_10deg.where(r_sq_annual_10deg>0.3,drop=True).lon_bins.values

ds_daily = xr.open_dataset(files_path + 'r_sq_clima_10degBins_agemaskCDW_daily_APR10.nc')
r_sq_clim_daily = ds_daily.r_sq_clim

# %%
longitude_slices = np.array([-63.5,-133.5,-243.5,-143.5,-173.5,-103.5, -33.5, -13.5, 76.5,-263.5])
## Check if high_correlation lons align with the regions we have selected:
print(np.isin(longitude_slices,high_corr_lons))
regions = ['West Antarctic Peninsula', 'Getz', 'Totten',\
           'Getz West', 'Glomar', 'Amundsen', 'Filchner', \
           'Riiser-Larsen', 'Amery', 'Denman'] # Note Getz East --> Getz for plotting
# Out:
# [ True  True False  True  True  True  True  True  True  True]

# %%
regions_selected = ['Getz', 'West Antarctic Peninsula', 'Glomar']
inds_regions = np.where(np.isin(regions, regions_selected))[0]
print(inds_regions)
# Out:
# [0 1 4]

# %%
longitude_slices[4]=-173.5
regions[4]= 'Glomar'

# %%
# ds_f3 = xr.open_dataset('/g/data/e14/qo9901/ASC_collab_CSHT_ds/agemaskCDW_volav_corr.nc')
# r_sq_annual_10deg_f3 = ds_f3.r_sq_annual
# ds_f3.close()

# high_corr_lons_f3 = r_sq_annual_10deg_f3.where(r_sq_annual_10deg_f3>0.3,drop=True).lon_bins.values

# %%
# Extract your x and y data
def plotcolors_ASC_annual(ax,x,y,norm0,cmap0):
    x = np.linspace(x.min().values,x.max().values,3001)
    y=y.interp(year=x)
    # Color values come from the same data
    color_values = y  # You want the color to reflect the same values being plotted
    
    # Build line segments for LineCollection
    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    cmap_0 = cm.get_cmap(cmap0, 256)
    # Normalize and set colormap
    norm = Normalize(vmin=-norm0, vmax=norm0)  # handle NaNs if present
    lc = LineCollection(segments, cmap=cmap_0, norm=norm)
    lc.set_array(color_values)
    lc.set_linewidth(2.5)
    lc.set_zorder(0) 
    # Plot

    ax.add_collection(lc)
    
    # Set axis limits
    ax.set_xlim(x.min(), x.max())
    ax.set_ylim(np.nanmin(y), np.nanmax(y))
    
    # Optional colorbar
    #cbar = plt.colorbar(lc, ax=ax)
    #cbar.set_label('CDW Volume Transport (×100)')  # customize label
    
    # Add labels or title if needed
def plotcolors_CSHT_annual(ax,x,y,norm0,cmap0):
    x = np.linspace(x.min().values,x.max().values,3001)
    y=y.interp(year=x)
    # Color values come from the same data
    color_values = y  # You want the color to reflect the same values being plotted
    
    # Build line segments for LineCollection
    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    cmap_0 = cm.get_cmap(cmap0, 256)
    # Normalize and set colormap
    
    norm = Normalize(vmin=(y.min()*0.8).values, vmax=(y.max()*0.8).values)  # handle NaNs if present
    lc = LineCollection(segments, cmap=cmap_0, norm=norm)
    lc.set_array(color_values)
    lc.set_linewidth(2.5)
    lc.set_zorder(0) 
    # Plot

    ax.add_collection(lc)
    
    # Set axis limits
    ax.set_xlim(x.min(), x.max())
    ax.set_ylim(np.nanmin(y), np.nanmax(y))
    
    # Optional colorbar
    #cbar = plt.colorbar(lc, ax=ax)
    #cbar.set_label('CDW Volume Transport (×100)')  # customize label
    
    # Add labels or title if needed
    
def plotcolors_ASC_clima(ax,x,y,norm0,cmap0):
    x = np.linspace(x.min().values,x.max().values,3001)
    y=y.interp(dayofyear=x)
    # Color values come from the same data
    color_values = y  # You want the color to reflect the same values being plotted
    
    # Build line segments for LineCollection
    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    cmap_0 = cm.get_cmap(cmap0, 256)
    # Normalize and set colormap
    norm = Normalize(vmin=-norm0, vmax=norm0)  # handle NaNs if present
    lc = LineCollection(segments, cmap=cmap_0, norm=norm)
    lc.set_array(color_values)
    lc.set_linewidth(2.5)
    lc.set_zorder(0) 
    # Plot

    ax.add_collection(lc)
    
    # Set axis limits
    ax.set_xlim(x.min(), x.max())
    ax.set_ylim(np.nanmin(y), np.nanmax(y))
    
    # Optional colorbar
    #cbar = plt.colorbar(lc, ax=ax)
    #cbar.set_label('CDW Volume Transport (×100)')  # customize label
    
    # Add labels or title if needed
def plotcolors_CSHT_clima(ax,x,y,norm0,cmap0):
    x = np.linspace(x.min().values,x.max().values,3001)
    y=y.interp(dayofyear=x)
    # Color values come from the same data
    color_values = y  # You want the color to reflect the same values being plotted
    
    # Build line segments for LineCollection
    points = np.array([x, y]).T.reshape(-1, 1, 2)
    segments = np.concatenate([points[:-1], points[1:]], axis=1)
    cmap_0 = cm.get_cmap(cmap0, 256)
    # Normalize and set colormap
    norm = Normalize(vmin=(y.min()*0.8).values, vmax=(y.max()*0.8).values)  # handle NaNs if present
    lc = LineCollection(segments, cmap=cmap_0, norm=norm)
    lc.set_array(color_values)
    lc.set_linewidth(2.5)
    lc.set_zorder(0) 
    # Plot

    ax.add_collection(lc)
    
    # Set axis limits
    ax.set_xlim(x.min(), x.max())
    ax.set_ylim(np.nanmin(y), np.nanmax(y))
    
    # Optional colorbar
    #cbar = plt.colorbar(lc, ax=ax)
    #cbar.set_label('CDW Volume Transport (×100)')  # customize label
    
    # Add labels or title if needed

# %%
fig, ax = plt.subplots()
x = U_along_annual_binned_CDW_volav.year  # Assuming time is your x-axis
y = (U_along_annual_binned_CDW_volav.U.sel(lon_bins=longitude_slices[0]) * 100)
#np.linspace(x.min().values,x.max().values,2001)
plotcolors_ASC_annual(ax,x,y,np.abs(2),cmocean.curl)

# %%
#yaxis for stacked plots
#plots:     |"a"|"b"  |"c" |"d"  |"e" |"f" |
maxASC  =  [8   ,2   ,0    ,2    ,1   ,-0.8]
minASC  =  [-9  ,-10  ,-18  ,-2 ,-4    ,-2.5  ]
maxPHT  =  [16  ,3   ,15   ,12    ,5   ,13  ]
minPHT  =  [-10 ,-1.5,-2.5 ,-7 ,-2.2,0   ]

#yticks for stacked plots
yticks_ASC = [[0,4,8] , [-2,0,2] , [-8,-4,0] , [0,1,2] , [-1,0,1] , [-1.6,-1.2,-0.8]]
yticks_PHT = [[-10,-5,0,5] , [-1,-0.5,0,0.5] , [-2,0,2,4,6] , [-8,-4,0] , [-2,-1,0,1] , [0,3,6]]

# %%
#years wuth eastward anomalies extracted from the compositess
yearsinds=[[1963, 1979, 1980, 1981, 1982, 1983, 1984, 1985, 1999, 2001] ,\
[1962, 1968, 1975, 1976, 1982, 1984, 2001, 2002, 2004, 2015],\
[1960, 1961, 1989, 1994, 1995, 1997, 2000, 2001, 2002, 2003]]

# %%
seasonal_xticks = [  0    , 31    , 59    , 90    , 119   , 150   ,  180  ,  211  , 242   ,  272  ,  304  , 334   ]
seasonal_xlabels= ['1/Jan','1/Feb','1/Mar','1/Apr','1/May','1/Jun','1/Jul','1/Aug','1/Sep','1/Oct','1/Nov','1/Dec']

# %% [markdown]
# testing old figure 4

# %%
### MOST UPDATED FIGURE 4
## bracket (a) in bold - outside of the box
fontsize=15


fig = plt.figure(figsize=(22*0.9, 14))
ASC_color='black'
CSHT_color='black'
outlinethickness=3.5
# Create a GridSpec for a 3x4 grid
grid = gs.GridSpec(nrows=2, ncols=3, figure=fig)
grid.update(hspace=0.2, wspace=0.3)  # Adjust vertical and horizontal spacing

# Initialize a list to store axes
axes = []

# Loop through the 3x4 grid to create subplots
for j in range(inds_regions.size):  # Loop over rows

    i = inds_regions[j]

    ax3 = fig.add_subplot(grid[0, j])
    ax4 = fig.add_subplot(grid[1, j])
    ###################
    ax3.set_title(regions[i] + ' (' + str(-longitude_slices[i]-5) + '-' \
                  + str(-longitude_slices[i]+5) + '$\degree$W)',fontsize=16)

    ax3_HT=ax3.twinx()
    ax3.plot(U_along_annual_binned_CDW_volav.year,U_along_annual_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='ASC',linewidth=outlinethickness,zorder=0,color=ASC_color)
    x=U_along_annual_binned_CDW_volav.year
    y=(U_along_annual_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100)
    plotcolors_ASC_annual(ax3,x,y,(0.5*np.max(np.abs(y))).values,'PiYG_r')#np.max(np.abs(y)).values
    #ax3.plot(U_along_annual_binned_CDW_volav.year,U_along_annual_binned_DSW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='DSW',color='k')
    # ax3.plot([1956,2024],[0,0],\
    #          linestyle='--',color='tab:blue')
    ax3.set_ylim([minASC[j],maxASC[j]])
    
    ax3_HT.plot(U_along_annual_binned_CDW_volav.year,(CSHT_annual_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12),\
                label='CSHT',color=CSHT_color,linewidth=outlinethickness,zorder=0)
    x=U_along_annual_binned_CDW_volav.year
    y=(CSHT_annual_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12)
    plotcolors_CSHT_annual(ax3_HT,x,y,np.max(np.abs(y)).values,'Reds_r')
    # ax3_HT.plot([1956,2024],[0,0],\
    #          linestyle='--',color='tab:orange')
    ax3_HT.set_ylim([minPHT[j],maxPHT[j]])
    # ax3.set_ylim(u_along_lims[i])
    # ax3.set_yticks([-3,-2,-1,0,1,2,3],labels=[-3,-2,-1,0,1,2,3],fontsize=14,color='tab:blue')
    if j == 0:
        ax3.set_ylabel('ASC speed [cm/s]',fontsize=fontsize,color=ASC_color, fontweight = 'bold')
        ax3.yaxis.set_label_coords(-0.1, 0.75)
    # ax3_HT.set_ylim(CSHT_lims[i])
    # ax3_HT.set_yticks([-10,-5,0,5,10],labels=[-10,-5,0,5,10],fontsize=14,color='tab:orange')
    if j == inds_regions.size-1:
        ax3_HT.set_ylabel('Poleward Heat Transport [TW]',fontsize=fontsize,color=CSHT_color, fontweight = 'bold')
        ax3_HT.yaxis.set_label_coords(1.1, 0.35)
    
    ax3.set_xticks(ticks=np.arange(1960,2021,20),labels=np.arange(1960,2021,20), fontsize=fontsize)
    ax3.grid(alpha = 0.5)
    ax3.set_xlim(1957,2020)
    ax3.set_xlabel('Year',fontsize=fontsize)
    ax3.tick_params(axis='y', colors=ASC_color,labelsize=fontsize)  # Left y-axis ticks and labels in blue
    ax3_HT.tick_params(axis='y', colors=CSHT_color,labelsize=fontsize) # Right y-axis ticks and labels in orange
    ax3.plot([yearsinds[j],yearsinds[j]],[np.array(yearsinds[j])*0-30,np.array(yearsinds[j])*0+30],':',color='silver',zorder=0)

    if j == 0:
        ax3.set_yticks(ax3.get_yticks()[1::2])
        ax3_HT.set_yticks(ax3_HT.get_yticks()[::2])
    if j == 1:
        ax3.set_yticks(ax3.get_yticks()[::2])
        ax3_HT.set_yticks(ax3_HT.get_yticks()[::2])        
    if j == 2:
        ax3_HT.set_yticks(ax3_HT.get_yticks()[1::2])

    ax3.set_yticklabels(ax3.get_yticks(), weight='bold')
    ax3_HT.set_yticklabels(ax3_HT.get_yticks(), weight='bold')
    ax3.annotate( 'r$^{2}$ = ' + str(np.round(r_sq_annual_10deg.sel(lon_bins = longitude_slices[i]).values,2)), \
             (0.7,0.05), xycoords='axes fraction', fontsize = fontsize, fontweight = 'bold', zorder = 600)  
    ax3.set_yticks(ticks=yticks_ASC[j],labels=yticks_ASC[j])
    ax3_HT.set_yticks(ticks=yticks_PHT[j],labels=yticks_PHT[j])
    ################
    
    ax4_HT=ax4.twinx()
    ax4.annotate( 'r$^{2}$ = ' + str(np.round(r_sq_clim_daily.sel(lon_bins = longitude_slices[i]).values,2)), \
                 (0.7,0.05), xycoords='axes fraction', fontsize = fontsize, fontweight = 'bold', zorder = 600)    
    
    ax4.plot(U_along_clima_binned_CDW_volav.dayofyear,U_along_clima_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='ASC',linewidth=outlinethickness,zorder=0,color=ASC_color)
    #ax4.plot(U_along_clima_binned_CDW_volav.dayofyear,U_along_clima_binned_DSW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='DSW',color='k')
    x=U_along_clima_binned_CDW_volav.dayofyear
    y=(U_along_clima_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100)
    plotcolors_ASC_clima(ax4,x,y,(1.1*np.max(np.abs(y))).values,'PiYG_r')#np.max(np.abs(y)).values
    # ax4.plot([0,365],[0,0],\
    #          linestyle='--',color='tab:blue')
    ax4.set_ylim([minASC[3+j],maxASC[3+j]])
    ax4_HT.plot(U_along_clima_binned_CDW_volav.dayofyear,(CSHT_clima_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12),\
                label='CSHT',color=CSHT_color,linewidth=outlinethickness,zorder=0)
    x=U_along_clima_binned_CDW_volav.dayofyear
    y=(CSHT_clima_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12)
    plotcolors_CSHT_clima(ax4_HT,x,y,np.max(np.abs(y)).values,'Reds_r')
    # ax4_HT.plot([0,365],[0,0],\
    #          linestyle='--',color='tab:orange')
    ax4_HT.set_ylim([minPHT[3+j],maxPHT[3+j]])

    if j == 0:    
        ax4.set_ylabel('ASC speed [cm/s]',fontsize=fontsize,color=ASC_color, fontweight = 'bold')
        ax4.yaxis.set_label_coords(-0.1, 0.75)
 
    if j == inds_regions.size-1:
        ax4_HT.set_ylabel('Poleward Heat Transport [TW]',fontsize=fontsize,color=CSHT_color, fontweight = 'bold')
        ax4_HT.yaxis.set_label_coords(1.1, 0.35)
    ax4.set_xlabel('Day of year',fontsize=fontsize)
    #ax4.set_xticks(ticks=np.arange(0,365,50),labels=np.arange(0,365,50),fontsize=fontsize)
    ax4_HT.set_xticks(ticks=[],labels=[])
    ax4.grid(alpha = 0.5)
    # Set tick colors
    ax4.tick_params(axis='y', colors=ASC_color,labelsize=fontsize) # Left y-axis ticks and labels in blue
    ax4_HT.tick_params(axis='y', colors=CSHT_color,labelsize=fontsize)  # Right y-axis ticks and labels in orange
    ax4_HT.set_xlim(0,360)
    ax4.set_xticks(ticks=seasonal_xticks)
    ax4.set_xticklabels(labels=seasonal_xlabels, fontsize=fontsize-2, rotation=60, ha='center')
    ax4.tick_params(axis='x',labelsize=fontsize-2, labelrotation=60)


    if j == 0:
        ax4_HT.set_yticks(ax4_HT.get_yticks()[:])
        ax4.set_yticks(ax4.get_yticks()[1::2])
    if j == 1:
        ax4.set_yticks(ax4.get_yticks()[1::2])
        ax4_HT.set_yticks(ax4_HT.get_yticks()[1::2])
    if j == 2:
        ax4.set_yticks(ax4.get_yticks()[::2])    
        ax4_HT.set_yticks(ax4_HT.get_yticks()[1::2])


    ax4.set_yticklabels(np.round(ax4.get_yticks(),1), weight='bold')
    ax4_HT.set_yticklabels(ax4_HT.get_yticks(), weight='bold')
    ax4.set_yticks(ticks=yticks_ASC[3+j],labels=yticks_ASC[3+j])
    ax4_HT.set_yticks(ticks=yticks_PHT[3+j],labels=yticks_PHT[3+j])

ax3.text(-2.9,0.5, 'Interannual', fontsize=18, transform = ax3.transAxes, va = 'center', ha = 'center', rotation = 90)
ax4.text(-2.9,0.5, 'Climatology', fontsize=18, transform = ax4.transAxes, va = 'center', ha = 'center', rotation = 90)

ax3.text(-2.75,1.07, '(a)', fontsize=fontsize, transform = ax3.transAxes, va = 'center', ha = 'center', fontweight = 'bold')
ax3.text(-1.4,1.07, '(b)', fontsize=fontsize, transform = ax3.transAxes, va = 'center', ha = 'center', fontweight = 'bold')
ax3.text(-0.1,1.07, '(c)', fontsize=fontsize, transform = ax3.transAxes, va = 'center', ha = 'center', fontweight = 'bold')
ax4.text(-2.75,1.07, '(d)', fontsize=fontsize, transform = ax4.transAxes, va = 'center', ha = 'center', fontweight = 'bold')
ax4.text(-1.4,1.07, '(e)', fontsize=fontsize, transform = ax4.transAxes, va = 'center', ha = 'center', fontweight = 'bold')
ax4.text(-0.1,1.07, '(f)', fontsize=fontsize, transform = ax4.transAxes, va = 'center', ha = 'center', fontweight = 'bold')

plt.tight_layout()
#figure_path = '/g/data/x77/wf4500/ASC_project/analysis_figs/selected_time_series_aug4_blacklines.png'
#plt.savefig(figure_path , dpi=300,bbox_inches='tight', pad_inches=0.1,facecolor='white')
## Show the plots
plt.tight_layout()
plt.show()

# %%
#test of angled transect

# %%
# check location of transect is good:
fig,ax_cric = plt.subplots(nrows = 1,ncols = 1,figsize = (10,5))
# new diagonal, cross-shelf transect:


# define transect start and end points:
lat1 = -77.8
lat0= -73
lon1 = -178.5
lon0 = -173.5

#plt.figure(figsize=(12,7))

# plot temperature:
plt.pcolormesh(ht.xt_ocean,ht.yt_ocean,ht,cmap=cmocean.dense)
plt.colorbar(label = 'Ocean Depth [m]')
plt.clim((0,3000))

# plot transect location:
plt.plot([lon0,lon1],[lat0,lat1],'r')

# plot bathymetry contours:
bath = plt.contour(ht.xt_ocean,ht.yt_ocean.sel(yt_ocean=slice(-78,-69)),ht.sel(yt_ocean=slice(-78,-69)),[300,500,700,1000],colors='k')
#plt.clabel(bath,levels=[1000],inline=True,inline_spacing=1)
plt.text(-170,-75.8,'1000 m isobath',rotation=-1, bbox=dict(facecolor='white',  # Set the face color of the box to white
                  edgecolor='black',  # Optional: Add a black edge to the box
                  boxstyle='round,pad=0.1',  # Define the box style and padding
                  alpha=0.8))
plt.text(-179.2,-77.8,'Glomar Transect',rotation=65,color='red')
ax_cric.xaxis.set_major_formatter(LongitudeFormatter())
ax_cric.yaxis.set_major_formatter(LatitudeFormatter())
plt.ylim(-78,-69)
plt.xlim(-195,-160)
plt.xlabel('Longitude',fontsize = 16)
plt.ylabel('Latitude',fontsize = 16)

plt.tight_layout()

# %%
lons = [lon1, lon0]
lats = [lat1, lat0]

yt_ocean = ht.yt_ocean
# get latitude of points along transect:
lat_transect = yt_ocean.sel(yt_ocean = slice(lats[0],lats[1])).values

# calculate slope and intercept of transect line:
slope = (lons[0] - lons[1])/(lats[0]-lats[1])
intercept = lons[0] - slope * lats[0]

# get longitude along transect and convert to xarray:
lon_transect = slope * lat_transect + intercept
lon_transect_t = xr.DataArray(lon_transect, dims = 'yt_ocean')
lon_transect_u = xr.DataArray(lon_transect, dims = 'yu_ocean')

# convert to xarray:
lat_transect_t = xr.DataArray(lat_transect, dims = 'yt_ocean')
lat_transect_u = xr.DataArray(lat_transect, dims = 'yu_ocean')

# %%
longitude_slices = np.array([-63.5,-133.5, -173.5])

## Check if high_correlation lons align with the regions we have selected:
print(np.isin(longitude_slices,high_corr_lons))
regions = ['West Antarctic Peninsula', 'Getz', 'Glomar_angled']

min_lat = np.append(np.array([-69, -74.25]), lat0)

vmin_range = np.array([-.2, -.05, -.05])
# for temp:
norm = [col.Normalize(vmin=-1.9,vmax=2.6),
col.Normalize(vmin=-1.8,vmax=1.5), 
col.Normalize(vmin=-1.8,vmax=1.5)]

levels=[np.arange(-1.9,2.6,.05), 
        np.arange(-1.8,1.55,.05), 
        np.arange(-1.8,1.55,.05)]
ticks = [[-1,0,1,2], [-1,0,1], [-1,0,1]]
# Out:
# [ True  True  True]

# %%
# import bathymetry:
start_time= '1958-01-01'
end_time= '2018-12-31'
hu_transect_og = importer(exp,catalog,'hu', frequency = 'fx') 
rho_og = importer(exp,catalog,'pot_rho_0',frequency='1mon',start_time=start_time,end_time=end_time,chunks={'time': 12})
#### U importing of iaf by intake has been quite wrong. So I ill import it manually
# u_og = importer(exp,catalog,'u',frequency='1mon',start_time=start_time,end_time=end_time,chunks={'time': 12})
temp_og = importer(exp,catalog,'temp',frequency='1mon',start_time=start_time,end_time=end_time,chunks={'time': 12}) - 273.15

# %%
df = catalog[exp].search(variable='u', frequency='1mon').df
print(df["path"])

sel = catalog[exp].search(variable='u', frequency='1mon')
df = sel.df

# Keep only monthly-mean files
df_mean = df[df["filename"].str.contains("monthly-mean")]
# Out:
# 0       /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output488/ocean/ocean-3d-u-1-monthly-mean-ym_1958_01.nc
# 1      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output488/ocean/ocean-3d-u-1-monthly-pow02-ym_1958_01.nc
# 2       /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output489/ocean/ocean-3d-u-1-monthly-mean-ym_1958_04.nc
# 3      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output489/ocean/ocean-3d-u-1-monthly-pow02-ym_1958_04.nc
# 4       /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output490/ocean/ocean-3d-u-1-monthly-mean-ym_1958_07.nc
# 5      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output490/ocean/ocean-3d-u-1-monthly-pow02-ym_1958_07.nc
# 6       /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output491/ocean/ocean-3d-u-1-monthly-mean-ym_1958_10.nc
# 7      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output491/ocean/ocean-3d-u-1-monthly-pow02-ym_1958_10.nc
# 8       /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output492/ocean/ocean-3d-u-1-monthly-mean-ym_1959_01.nc
# 9      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output492/ocean/ocean-3d-u-1-monthly-pow02-ym_1959_01.nc
# 10      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output493/ocean/ocean-3d-u-1-monthly-mean-ym_1959_04.nc
# 11     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output493/ocean/ocean-3d-u-1-monthly-pow02-ym_1959_04.nc
# 12      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output494/ocean/ocean-3d-u-1-monthly-mean-ym_1959_07.nc
# 13     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output494/ocean/ocean-3d-u-1-monthly-pow02-ym_1959_07.nc
# 14      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output495/ocean/ocean-3d-u-1-monthly-mean-ym_1959_10.nc
# 15     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output495/ocean/ocean-3d-u-1-monthly-pow02-ym_1959_10.nc
# 16      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output496/ocean/ocean-3d-u-1-monthly-mean-ym_1960_01.nc
# 17     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output496/ocean/ocean-3d-u-1-monthly-pow02-ym_1960_01.nc
# 18      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output497/ocean/ocean-3d-u-1-monthly-mean-ym_1960_04.nc
# 19     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output497/ocean/ocean-3d-u-1-monthly-pow02-ym_1960_04.nc
# 20      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output498/ocean/ocean-3d-u-1-monthly-mean-ym_1960_07.nc
# 21     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output498/ocean/ocean-3d-u-1-monthly-pow02-ym_1960_07.nc
# 22      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output499/ocean/ocean-3d-u-1-monthly-mean-ym_1960_10.nc
# 23     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output499/ocean/ocean-3d-u-1-monthly-pow02-ym_1960_10.nc
# 24      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output500/ocean/ocean-3d-u-1-monthly-mean-ym_1961_01.nc
# 25     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output500/ocean/ocean-3d-u-1-monthly-pow02-ym_1961_01.nc
# 26      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output501/ocean/ocean-3d-u-1-monthly-mean-ym_1961_04.nc
# 27     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output501/ocean/ocean-3d-u-1-monthly-pow02-ym_1961_04.nc
# 28      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output502/ocean/ocean-3d-u-1-monthly-mean-ym_1961_07.nc
# 29     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output502/ocean/ocean-3d-u-1-monthly-pow02-ym_1961_07.nc
# 30      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output503/ocean/ocean-3d-u-1-monthly-mean-ym_1961_10.nc
# 31     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output503/ocean/ocean-3d-u-1-monthly-pow02-ym_1961_10.nc
# 32      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output504/ocean/ocean-3d-u-1-monthly-mean-ym_1962_01.nc
# 33     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output504/ocean/ocean-3d-u-1-monthly-pow02-ym_1962_01.nc
# 34      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output505/ocean/ocean-3d-u-1-monthly-mean-ym_1962_04.nc
# 35     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output505/ocean/ocean-3d-u-1-monthly-pow02-ym_1962_04.nc
# 36      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output506/ocean/ocean-3d-u-1-monthly-mean-ym_1962_07.nc
# 37     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output506/ocean/ocean-3d-u-1-monthly-pow02-ym_1962_07.nc
# 38      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output507/ocean/ocean-3d-u-1-monthly-mean-ym_1962_10.nc
# 39     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output507/ocean/ocean-3d-u-1-monthly-pow02-ym_1962_10.nc
# 40      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output508/ocean/ocean-3d-u-1-monthly-mean-ym_1963_01.nc
# 41     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output508/ocean/ocean-3d-u-1-monthly-pow02-ym_1963_01.nc
# 42      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output509/ocean/ocean-3d-u-1-monthly-mean-ym_1963_04.nc
# 43     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output509/ocean/ocean-3d-u-1-monthly-pow02-ym_1963_04.nc
# 44      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output510/ocean/ocean-3d-u-1-monthly-mean-ym_1963_07.nc
# 45     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output510/ocean/ocean-3d-u-1-monthly-pow02-ym_1963_07.nc
# 46      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output511/ocean/ocean-3d-u-1-monthly-mean-ym_1963_10.nc
# 47     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output511/ocean/ocean-3d-u-1-monthly-pow02-ym_1963_10.nc
# 48      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output512/ocean/ocean-3d-u-1-monthly-mean-ym_1964_01.nc
# 49     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output512/ocean/ocean-3d-u-1-monthly-pow02-ym_1964_01.nc
# 50      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output513/ocean/ocean-3d-u-1-monthly-mean-ym_1964_04.nc
# 51     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output513/ocean/ocean-3d-u-1-monthly-pow02-ym_1964_04.nc
# 52      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output514/ocean/ocean-3d-u-1-monthly-mean-ym_1964_07.nc
# 53     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output514/ocean/ocean-3d-u-1-monthly-pow02-ym_1964_07.nc
# 54      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output515/ocean/ocean-3d-u-1-monthly-mean-ym_1964_10.nc
# 55     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output515/ocean/ocean-3d-u-1-monthly-pow02-ym_1964_10.nc
# 56      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output516/ocean/ocean-3d-u-1-monthly-mean-ym_1965_01.nc
# 57     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output516/ocean/ocean-3d-u-1-monthly-pow02-ym_1965_01.nc
# 58      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output517/ocean/ocean-3d-u-1-monthly-mean-ym_1965_04.nc
# 59     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output517/ocean/ocean-3d-u-1-monthly-pow02-ym_1965_04.nc
# 60      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output518/ocean/ocean-3d-u-1-monthly-mean-ym_1965_07.nc
# 61     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output518/ocean/ocean-3d-u-1-monthly-pow02-ym_1965_07.nc
# 62      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output519/ocean/ocean-3d-u-1-monthly-mean-ym_1965_10.nc
# 63     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output519/ocean/ocean-3d-u-1-monthly-pow02-ym_1965_10.nc
# 64      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output520/ocean/ocean-3d-u-1-monthly-mean-ym_1966_01.nc
# 65     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output520/ocean/ocean-3d-u-1-monthly-pow02-ym_1966_01.nc
# 66      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output521/ocean/ocean-3d-u-1-monthly-mean-ym_1966_04.nc
# 67     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output521/ocean/ocean-3d-u-1-monthly-pow02-ym_1966_04.nc
# 68      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output522/ocean/ocean-3d-u-1-monthly-mean-ym_1966_07.nc
# 69     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output522/ocean/ocean-3d-u-1-monthly-pow02-ym_1966_07.nc
# 70      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output523/ocean/ocean-3d-u-1-monthly-mean-ym_1966_10.nc
# 71     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output523/ocean/ocean-3d-u-1-monthly-pow02-ym_1966_10.nc
# 72      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output524/ocean/ocean-3d-u-1-monthly-mean-ym_1967_01.nc
# 73     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output524/ocean/ocean-3d-u-1-monthly-pow02-ym_1967_01.nc
# 74      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output525/ocean/ocean-3d-u-1-monthly-mean-ym_1967_04.nc
# 75     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output525/ocean/ocean-3d-u-1-monthly-pow02-ym_1967_04.nc
# 76      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output526/ocean/ocean-3d-u-1-monthly-mean-ym_1967_07.nc
# 77     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output526/ocean/ocean-3d-u-1-monthly-pow02-ym_1967_07.nc
# 78      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output527/ocean/ocean-3d-u-1-monthly-mean-ym_1967_10.nc
# 79     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output527/ocean/ocean-3d-u-1-monthly-pow02-ym_1967_10.nc
# 80      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output528/ocean/ocean-3d-u-1-monthly-mean-ym_1968_01.nc
# 81     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output528/ocean/ocean-3d-u-1-monthly-pow02-ym_1968_01.nc
# 82      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output529/ocean/ocean-3d-u-1-monthly-mean-ym_1968_04.nc
# 83     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output529/ocean/ocean-3d-u-1-monthly-pow02-ym_1968_04.nc
# 84      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output530/ocean/ocean-3d-u-1-monthly-mean-ym_1968_07.nc
# 85     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output530/ocean/ocean-3d-u-1-monthly-pow02-ym_1968_07.nc
# 86      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output531/ocean/ocean-3d-u-1-monthly-mean-ym_1968_10.nc
# 87     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output531/ocean/ocean-3d-u-1-monthly-pow02-ym_1968_10.nc
# 88      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output532/ocean/ocean-3d-u-1-monthly-mean-ym_1969_01.nc
# 89     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output532/ocean/ocean-3d-u-1-monthly-pow02-ym_1969_01.nc
# 90      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output533/ocean/ocean-3d-u-1-monthly-mean-ym_1969_04.nc
# 91     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output533/ocean/ocean-3d-u-1-monthly-pow02-ym_1969_04.nc
# 92      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output534/ocean/ocean-3d-u-1-monthly-mean-ym_1969_07.nc
# 93     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output534/ocean/ocean-3d-u-1-monthly-pow02-ym_1969_07.nc
# 94      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output535/ocean/ocean-3d-u-1-monthly-mean-ym_1969_10.nc
# 95     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output535/ocean/ocean-3d-u-1-monthly-pow02-ym_1969_10.nc
# 96      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output536/ocean/ocean-3d-u-1-monthly-mean-ym_1970_01.nc
# 97     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output536/ocean/ocean-3d-u-1-monthly-pow02-ym_1970_01.nc
# 98      /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output537/ocean/ocean-3d-u-1-monthly-mean-ym_1970_04.nc
# 99     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output537/ocean/ocean-3d-u-1-monthly-pow02-ym_1970_04.nc
# 100     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output538/ocean/ocean-3d-u-1-monthly-mean-ym_1970_07.nc
# 101    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output538/ocean/ocean-3d-u-1-monthly-pow02-ym_1970_07.nc
# 102     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output539/ocean/ocean-3d-u-1-monthly-mean-ym_1970_10.nc
# 103    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output539/ocean/ocean-3d-u-1-monthly-pow02-ym_1970_10.nc
# 104     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output540/ocean/ocean-3d-u-1-monthly-mean-ym_1971_01.nc
# 105    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output540/ocean/ocean-3d-u-1-monthly-pow02-ym_1971_01.nc
# 106     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output541/ocean/ocean-3d-u-1-monthly-mean-ym_1971_04.nc
# 107    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output541/ocean/ocean-3d-u-1-monthly-pow02-ym_1971_04.nc
# 108     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output542/ocean/ocean-3d-u-1-monthly-mean-ym_1971_07.nc
# 109    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output542/ocean/ocean-3d-u-1-monthly-pow02-ym_1971_07.nc
# 110     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output543/ocean/ocean-3d-u-1-monthly-mean-ym_1971_10.nc
# 111    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output543/ocean/ocean-3d-u-1-monthly-pow02-ym_1971_10.nc
# 112     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output544/ocean/ocean-3d-u-1-monthly-mean-ym_1972_01.nc
# 113    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output544/ocean/ocean-3d-u-1-monthly-pow02-ym_1972_01.nc
# 114     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output545/ocean/ocean-3d-u-1-monthly-mean-ym_1972_04.nc
# 115    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output545/ocean/ocean-3d-u-1-monthly-pow02-ym_1972_04.nc
# 116     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output546/ocean/ocean-3d-u-1-monthly-mean-ym_1972_07.nc
# 117    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output546/ocean/ocean-3d-u-1-monthly-pow02-ym_1972_07.nc
# 118     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output547/ocean/ocean-3d-u-1-monthly-mean-ym_1972_10.nc
# 119    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output547/ocean/ocean-3d-u-1-monthly-pow02-ym_1972_10.nc
# 120     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output548/ocean/ocean-3d-u-1-monthly-mean-ym_1973_01.nc
# 121    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output548/ocean/ocean-3d-u-1-monthly-pow02-ym_1973_01.nc
# 122     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output549/ocean/ocean-3d-u-1-monthly-mean-ym_1973_04.nc
# 123    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output549/ocean/ocean-3d-u-1-monthly-pow02-ym_1973_04.nc
# 124     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output550/ocean/ocean-3d-u-1-monthly-mean-ym_1973_07.nc
# 125    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output550/ocean/ocean-3d-u-1-monthly-pow02-ym_1973_07.nc
# 126     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output551/ocean/ocean-3d-u-1-monthly-mean-ym_1973_10.nc
# 127    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output551/ocean/ocean-3d-u-1-monthly-pow02-ym_1973_10.nc
# 128     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output552/ocean/ocean-3d-u-1-monthly-mean-ym_1974_01.nc
# 129    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output552/ocean/ocean-3d-u-1-monthly-pow02-ym_1974_01.nc
# 130     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output553/ocean/ocean-3d-u-1-monthly-mean-ym_1974_04.nc
# 131    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output553/ocean/ocean-3d-u-1-monthly-pow02-ym_1974_04.nc
# 132     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output554/ocean/ocean-3d-u-1-monthly-mean-ym_1974_07.nc
# 133    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output554/ocean/ocean-3d-u-1-monthly-pow02-ym_1974_07.nc
# 134     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output555/ocean/ocean-3d-u-1-monthly-mean-ym_1974_10.nc
# 135    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output555/ocean/ocean-3d-u-1-monthly-pow02-ym_1974_10.nc
# 136     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output556/ocean/ocean-3d-u-1-monthly-mean-ym_1975_01.nc
# 137    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output556/ocean/ocean-3d-u-1-monthly-pow02-ym_1975_01.nc
# 138     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output557/ocean/ocean-3d-u-1-monthly-mean-ym_1975_04.nc
# 139    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output557/ocean/ocean-3d-u-1-monthly-pow02-ym_1975_04.nc
# 140     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output558/ocean/ocean-3d-u-1-monthly-mean-ym_1975_07.nc
# 141    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output558/ocean/ocean-3d-u-1-monthly-pow02-ym_1975_07.nc
# 142     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output559/ocean/ocean-3d-u-1-monthly-mean-ym_1975_10.nc
# 143    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output559/ocean/ocean-3d-u-1-monthly-pow02-ym_1975_10.nc
# 144     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output560/ocean/ocean-3d-u-1-monthly-mean-ym_1976_01.nc
# 145    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output560/ocean/ocean-3d-u-1-monthly-pow02-ym_1976_01.nc
# 146     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output561/ocean/ocean-3d-u-1-monthly-mean-ym_1976_04.nc
# 147    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output561/ocean/ocean-3d-u-1-monthly-pow02-ym_1976_04.nc
# 148     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output562/ocean/ocean-3d-u-1-monthly-mean-ym_1976_07.nc
# 149    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output562/ocean/ocean-3d-u-1-monthly-pow02-ym_1976_07.nc
# 150     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output563/ocean/ocean-3d-u-1-monthly-mean-ym_1976_10.nc
# 151    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output563/ocean/ocean-3d-u-1-monthly-pow02-ym_1976_10.nc
# 152     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output564/ocean/ocean-3d-u-1-monthly-mean-ym_1977_01.nc
# 153    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output564/ocean/ocean-3d-u-1-monthly-pow02-ym_1977_01.nc
# 154     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output565/ocean/ocean-3d-u-1-monthly-mean-ym_1977_04.nc
# 155    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output565/ocean/ocean-3d-u-1-monthly-pow02-ym_1977_04.nc
# 156     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output566/ocean/ocean-3d-u-1-monthly-mean-ym_1977_07.nc
# 157    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output566/ocean/ocean-3d-u-1-monthly-pow02-ym_1977_07.nc
# 158     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output567/ocean/ocean-3d-u-1-monthly-mean-ym_1977_10.nc
# 159    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output567/ocean/ocean-3d-u-1-monthly-pow02-ym_1977_10.nc
# 160     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output568/ocean/ocean-3d-u-1-monthly-mean-ym_1978_01.nc
# 161    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output568/ocean/ocean-3d-u-1-monthly-pow02-ym_1978_01.nc
# 162     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output569/ocean/ocean-3d-u-1-monthly-mean-ym_1978_04.nc
# 163    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output569/ocean/ocean-3d-u-1-monthly-pow02-ym_1978_04.nc
# 164     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output570/ocean/ocean-3d-u-1-monthly-mean-ym_1978_07.nc
# 165    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output570/ocean/ocean-3d-u-1-monthly-pow02-ym_1978_07.nc
# 166     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output571/ocean/ocean-3d-u-1-monthly-mean-ym_1978_10.nc
# 167    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output571/ocean/ocean-3d-u-1-monthly-pow02-ym_1978_10.nc
# 168     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output572/ocean/ocean-3d-u-1-monthly-mean-ym_1979_01.nc
# 169    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output572/ocean/ocean-3d-u-1-monthly-pow02-ym_1979_01.nc
# 170     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output573/ocean/ocean-3d-u-1-monthly-mean-ym_1979_04.nc
# 171    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output573/ocean/ocean-3d-u-1-monthly-pow02-ym_1979_04.nc
# 172     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output574/ocean/ocean-3d-u-1-monthly-mean-ym_1979_07.nc
# 173    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output574/ocean/ocean-3d-u-1-monthly-pow02-ym_1979_07.nc
# 174     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output575/ocean/ocean-3d-u-1-monthly-mean-ym_1979_10.nc
# 175    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output575/ocean/ocean-3d-u-1-monthly-pow02-ym_1979_10.nc
# 176     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output576/ocean/ocean-3d-u-1-monthly-mean-ym_1980_01.nc
# 177    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output576/ocean/ocean-3d-u-1-monthly-pow02-ym_1980_01.nc
# 178     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output577/ocean/ocean-3d-u-1-monthly-mean-ym_1980_04.nc
# 179    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output577/ocean/ocean-3d-u-1-monthly-pow02-ym_1980_04.nc
# 180     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output578/ocean/ocean-3d-u-1-monthly-mean-ym_1980_07.nc
# 181    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output578/ocean/ocean-3d-u-1-monthly-pow02-ym_1980_07.nc
# 182     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output579/ocean/ocean-3d-u-1-monthly-mean-ym_1980_10.nc
# 183    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output579/ocean/ocean-3d-u-1-monthly-pow02-ym_1980_10.nc
# 184     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output580/ocean/ocean-3d-u-1-monthly-mean-ym_1981_01.nc
# 185    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output580/ocean/ocean-3d-u-1-monthly-pow02-ym_1981_01.nc
# 186     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output581/ocean/ocean-3d-u-1-monthly-mean-ym_1981_04.nc
# 187    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output581/ocean/ocean-3d-u-1-monthly-pow02-ym_1981_04.nc
# 188     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output582/ocean/ocean-3d-u-1-monthly-mean-ym_1981_07.nc
# 189    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output582/ocean/ocean-3d-u-1-monthly-pow02-ym_1981_07.nc
# 190     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output583/ocean/ocean-3d-u-1-monthly-mean-ym_1981_10.nc
# 191    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output583/ocean/ocean-3d-u-1-monthly-pow02-ym_1981_10.nc
# 192     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output584/ocean/ocean-3d-u-1-monthly-mean-ym_1982_01.nc
# 193    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output584/ocean/ocean-3d-u-1-monthly-pow02-ym_1982_01.nc
# 194     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output585/ocean/ocean-3d-u-1-monthly-mean-ym_1982_04.nc
# 195    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output585/ocean/ocean-3d-u-1-monthly-pow02-ym_1982_04.nc
# 196     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output586/ocean/ocean-3d-u-1-monthly-mean-ym_1982_07.nc
# 197    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output586/ocean/ocean-3d-u-1-monthly-pow02-ym_1982_07.nc
# 198     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output587/ocean/ocean-3d-u-1-monthly-mean-ym_1982_10.nc
# 199    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output587/ocean/ocean-3d-u-1-monthly-pow02-ym_1982_10.nc
# 200     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output588/ocean/ocean-3d-u-1-monthly-mean-ym_1983_01.nc
# 201    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output588/ocean/ocean-3d-u-1-monthly-pow02-ym_1983_01.nc
# 202     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output589/ocean/ocean-3d-u-1-monthly-mean-ym_1983_04.nc
# 203    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output589/ocean/ocean-3d-u-1-monthly-pow02-ym_1983_04.nc
# 204     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output590/ocean/ocean-3d-u-1-monthly-mean-ym_1983_07.nc
# 205    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output590/ocean/ocean-3d-u-1-monthly-pow02-ym_1983_07.nc
# 206     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output591/ocean/ocean-3d-u-1-monthly-mean-ym_1983_10.nc
# 207    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output591/ocean/ocean-3d-u-1-monthly-pow02-ym_1983_10.nc
# 208     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output592/ocean/ocean-3d-u-1-monthly-mean-ym_1984_01.nc
# 209    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output592/ocean/ocean-3d-u-1-monthly-pow02-ym_1984_01.nc
# 210     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output593/ocean/ocean-3d-u-1-monthly-mean-ym_1984_04.nc
# 211    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output593/ocean/ocean-3d-u-1-monthly-pow02-ym_1984_04.nc
# 212     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output594/ocean/ocean-3d-u-1-monthly-mean-ym_1984_07.nc
# 213    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output594/ocean/ocean-3d-u-1-monthly-pow02-ym_1984_07.nc
# 214     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output595/ocean/ocean-3d-u-1-monthly-mean-ym_1984_10.nc
# 215    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output595/ocean/ocean-3d-u-1-monthly-pow02-ym_1984_10.nc
# 216     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output596/ocean/ocean-3d-u-1-monthly-mean-ym_1985_01.nc
# 217    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output596/ocean/ocean-3d-u-1-monthly-pow02-ym_1985_01.nc
# 218     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output597/ocean/ocean-3d-u-1-monthly-mean-ym_1985_04.nc
# 219    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output597/ocean/ocean-3d-u-1-monthly-pow02-ym_1985_04.nc
# 220     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output598/ocean/ocean-3d-u-1-monthly-mean-ym_1985_07.nc
# 221    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output598/ocean/ocean-3d-u-1-monthly-pow02-ym_1985_07.nc
# 222     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output599/ocean/ocean-3d-u-1-monthly-mean-ym_1985_10.nc
# 223    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output599/ocean/ocean-3d-u-1-monthly-pow02-ym_1985_10.nc
# 224     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output600/ocean/ocean-3d-u-1-monthly-mean-ym_1986_01.nc
# 225    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output600/ocean/ocean-3d-u-1-monthly-pow02-ym_1986_01.nc
# 226     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output601/ocean/ocean-3d-u-1-monthly-mean-ym_1986_04.nc
# 227    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output601/ocean/ocean-3d-u-1-monthly-pow02-ym_1986_04.nc
# 228     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output602/ocean/ocean-3d-u-1-monthly-mean-ym_1986_07.nc
# 229    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output602/ocean/ocean-3d-u-1-monthly-pow02-ym_1986_07.nc
# 230     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output603/ocean/ocean-3d-u-1-monthly-mean-ym_1986_10.nc
# 231    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output603/ocean/ocean-3d-u-1-monthly-pow02-ym_1986_10.nc
# 232     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output604/ocean/ocean-3d-u-1-monthly-mean-ym_1987_01.nc
# 233    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output604/ocean/ocean-3d-u-1-monthly-pow02-ym_1987_01.nc
# 234     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output605/ocean/ocean-3d-u-1-monthly-mean-ym_1987_04.nc
# 235    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output605/ocean/ocean-3d-u-1-monthly-pow02-ym_1987_04.nc
# 236     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output606/ocean/ocean-3d-u-1-monthly-mean-ym_1987_07.nc
# 237    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output606/ocean/ocean-3d-u-1-monthly-pow02-ym_1987_07.nc
# 238     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output607/ocean/ocean-3d-u-1-monthly-mean-ym_1987_10.nc
# 239    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output607/ocean/ocean-3d-u-1-monthly-pow02-ym_1987_10.nc
# 240     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output608/ocean/ocean-3d-u-1-monthly-mean-ym_1988_01.nc
# 241    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output608/ocean/ocean-3d-u-1-monthly-pow02-ym_1988_01.nc
# 242     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output609/ocean/ocean-3d-u-1-monthly-mean-ym_1988_04.nc
# 243    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output609/ocean/ocean-3d-u-1-monthly-pow02-ym_1988_04.nc
# 244     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output610/ocean/ocean-3d-u-1-monthly-mean-ym_1988_07.nc
# 245    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output610/ocean/ocean-3d-u-1-monthly-pow02-ym_1988_07.nc
# 246     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output611/ocean/ocean-3d-u-1-monthly-mean-ym_1988_10.nc
# 247    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output611/ocean/ocean-3d-u-1-monthly-pow02-ym_1988_10.nc
# 248     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output612/ocean/ocean-3d-u-1-monthly-mean-ym_1989_01.nc
# 249    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output612/ocean/ocean-3d-u-1-monthly-pow02-ym_1989_01.nc
# 250     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output613/ocean/ocean-3d-u-1-monthly-mean-ym_1989_04.nc
# 251    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output613/ocean/ocean-3d-u-1-monthly-pow02-ym_1989_04.nc
# 252     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output614/ocean/ocean-3d-u-1-monthly-mean-ym_1989_07.nc
# 253    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output614/ocean/ocean-3d-u-1-monthly-pow02-ym_1989_07.nc
# 254     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output615/ocean/ocean-3d-u-1-monthly-mean-ym_1989_10.nc
# 255    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output615/ocean/ocean-3d-u-1-monthly-pow02-ym_1989_10.nc
# 256     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output616/ocean/ocean-3d-u-1-monthly-mean-ym_1990_01.nc
# 257    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output616/ocean/ocean-3d-u-1-monthly-pow02-ym_1990_01.nc
# 258     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output617/ocean/ocean-3d-u-1-monthly-mean-ym_1990_04.nc
# 259    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output617/ocean/ocean-3d-u-1-monthly-pow02-ym_1990_04.nc
# 260     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output618/ocean/ocean-3d-u-1-monthly-mean-ym_1990_07.nc
# 261    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output618/ocean/ocean-3d-u-1-monthly-pow02-ym_1990_07.nc
# 262     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output619/ocean/ocean-3d-u-1-monthly-mean-ym_1990_10.nc
# 263    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output619/ocean/ocean-3d-u-1-monthly-pow02-ym_1990_10.nc
# 264     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output620/ocean/ocean-3d-u-1-monthly-mean-ym_1991_01.nc
# 265    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output620/ocean/ocean-3d-u-1-monthly-pow02-ym_1991_01.nc
# 266     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output621/ocean/ocean-3d-u-1-monthly-mean-ym_1991_04.nc
# 267    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output621/ocean/ocean-3d-u-1-monthly-pow02-ym_1991_04.nc
# 268     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output622/ocean/ocean-3d-u-1-monthly-mean-ym_1991_07.nc
# 269    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output622/ocean/ocean-3d-u-1-monthly-pow02-ym_1991_07.nc
# 270     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output623/ocean/ocean-3d-u-1-monthly-mean-ym_1991_10.nc
# 271    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output623/ocean/ocean-3d-u-1-monthly-pow02-ym_1991_10.nc
# 272     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output624/ocean/ocean-3d-u-1-monthly-mean-ym_1992_01.nc
# 273    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output624/ocean/ocean-3d-u-1-monthly-pow02-ym_1992_01.nc
# 274     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output625/ocean/ocean-3d-u-1-monthly-mean-ym_1992_04.nc
# 275    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output625/ocean/ocean-3d-u-1-monthly-pow02-ym_1992_04.nc
# 276     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output626/ocean/ocean-3d-u-1-monthly-mean-ym_1992_07.nc
# 277    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output626/ocean/ocean-3d-u-1-monthly-pow02-ym_1992_07.nc
# 278     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output627/ocean/ocean-3d-u-1-monthly-mean-ym_1992_10.nc
# 279    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output627/ocean/ocean-3d-u-1-monthly-pow02-ym_1992_10.nc
# 280     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output628/ocean/ocean-3d-u-1-monthly-mean-ym_1993_01.nc
# 281    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output628/ocean/ocean-3d-u-1-monthly-pow02-ym_1993_01.nc
# 282     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output629/ocean/ocean-3d-u-1-monthly-mean-ym_1993_04.nc
# 283    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output629/ocean/ocean-3d-u-1-monthly-pow02-ym_1993_04.nc
# 284     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output630/ocean/ocean-3d-u-1-monthly-mean-ym_1993_07.nc
# 285    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output630/ocean/ocean-3d-u-1-monthly-pow02-ym_1993_07.nc
# 286     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output631/ocean/ocean-3d-u-1-monthly-mean-ym_1993_10.nc
# 287    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output631/ocean/ocean-3d-u-1-monthly-pow02-ym_1993_10.nc
# 288     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output632/ocean/ocean-3d-u-1-monthly-mean-ym_1994_01.nc
# 289    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output632/ocean/ocean-3d-u-1-monthly-pow02-ym_1994_01.nc
# 290     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output633/ocean/ocean-3d-u-1-monthly-mean-ym_1994_04.nc
# 291    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output633/ocean/ocean-3d-u-1-monthly-pow02-ym_1994_04.nc
# 292     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output634/ocean/ocean-3d-u-1-monthly-mean-ym_1994_07.nc
# 293    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output634/ocean/ocean-3d-u-1-monthly-pow02-ym_1994_07.nc
# 294     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output635/ocean/ocean-3d-u-1-monthly-mean-ym_1994_10.nc
# 295    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output635/ocean/ocean-3d-u-1-monthly-pow02-ym_1994_10.nc
# 296     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output636/ocean/ocean-3d-u-1-monthly-mean-ym_1995_01.nc
# 297    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output636/ocean/ocean-3d-u-1-monthly-pow02-ym_1995_01.nc
# 298     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output637/ocean/ocean-3d-u-1-monthly-mean-ym_1995_04.nc
# 299    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output637/ocean/ocean-3d-u-1-monthly-pow02-ym_1995_04.nc
# 300     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output638/ocean/ocean-3d-u-1-monthly-mean-ym_1995_07.nc
# 301    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output638/ocean/ocean-3d-u-1-monthly-pow02-ym_1995_07.nc
# 302     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output639/ocean/ocean-3d-u-1-monthly-mean-ym_1995_10.nc
# 303    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output639/ocean/ocean-3d-u-1-monthly-pow02-ym_1995_10.nc
# 304     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output640/ocean/ocean-3d-u-1-monthly-mean-ym_1996_01.nc
# 305    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output640/ocean/ocean-3d-u-1-monthly-pow02-ym_1996_01.nc
# 306     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output641/ocean/ocean-3d-u-1-monthly-mean-ym_1996_04.nc
# 307    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output641/ocean/ocean-3d-u-1-monthly-pow02-ym_1996_04.nc
# 308     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output642/ocean/ocean-3d-u-1-monthly-mean-ym_1996_07.nc
# 309    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output642/ocean/ocean-3d-u-1-monthly-pow02-ym_1996_07.nc
# 310     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output643/ocean/ocean-3d-u-1-monthly-mean-ym_1996_10.nc
# 311    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output643/ocean/ocean-3d-u-1-monthly-pow02-ym_1996_10.nc
# 312     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output644/ocean/ocean-3d-u-1-monthly-mean-ym_1997_01.nc
# 313    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output644/ocean/ocean-3d-u-1-monthly-pow02-ym_1997_01.nc
# 314     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output645/ocean/ocean-3d-u-1-monthly-mean-ym_1997_04.nc
# 315    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output645/ocean/ocean-3d-u-1-monthly-pow02-ym_1997_04.nc
# 316     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output646/ocean/ocean-3d-u-1-monthly-mean-ym_1997_07.nc
# 317    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output646/ocean/ocean-3d-u-1-monthly-pow02-ym_1997_07.nc
# 318     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output647/ocean/ocean-3d-u-1-monthly-mean-ym_1997_10.nc
# 319    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output647/ocean/ocean-3d-u-1-monthly-pow02-ym_1997_10.nc
# 320     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output648/ocean/ocean-3d-u-1-monthly-mean-ym_1998_01.nc
# 321    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output648/ocean/ocean-3d-u-1-monthly-pow02-ym_1998_01.nc
# 322     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output649/ocean/ocean-3d-u-1-monthly-mean-ym_1998_04.nc
# 323    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output649/ocean/ocean-3d-u-1-monthly-pow02-ym_1998_04.nc
# 324     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output650/ocean/ocean-3d-u-1-monthly-mean-ym_1998_07.nc
# 325    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output650/ocean/ocean-3d-u-1-monthly-pow02-ym_1998_07.nc
# 326     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output651/ocean/ocean-3d-u-1-monthly-mean-ym_1998_10.nc
# 327    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output651/ocean/ocean-3d-u-1-monthly-pow02-ym_1998_10.nc
# 328     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output652/ocean/ocean-3d-u-1-monthly-mean-ym_1999_01.nc
# 329    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output652/ocean/ocean-3d-u-1-monthly-pow02-ym_1999_01.nc
# 330     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output653/ocean/ocean-3d-u-1-monthly-mean-ym_1999_04.nc
# 331    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output653/ocean/ocean-3d-u-1-monthly-pow02-ym_1999_04.nc
# 332     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output654/ocean/ocean-3d-u-1-monthly-mean-ym_1999_07.nc
# 333    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output654/ocean/ocean-3d-u-1-monthly-pow02-ym_1999_07.nc
# 334     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output655/ocean/ocean-3d-u-1-monthly-mean-ym_1999_10.nc
# 335    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output655/ocean/ocean-3d-u-1-monthly-pow02-ym_1999_10.nc
# 336     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output656/ocean/ocean-3d-u-1-monthly-mean-ym_2000_01.nc
# 337    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output656/ocean/ocean-3d-u-1-monthly-pow02-ym_2000_01.nc
# 338     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output657/ocean/ocean-3d-u-1-monthly-mean-ym_2000_04.nc
# 339    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output657/ocean/ocean-3d-u-1-monthly-pow02-ym_2000_04.nc
# 340     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output658/ocean/ocean-3d-u-1-monthly-mean-ym_2000_07.nc
# 341    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output658/ocean/ocean-3d-u-1-monthly-pow02-ym_2000_07.nc
# ...
# 374     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output675/ocean/ocean-3d-u-1-monthly-mean-ym_2004_10.nc
# 375    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output675/ocean/ocean-3d-u-1-monthly-pow02-ym_2004_10.nc
# 376     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output676/ocean/ocean-3d-u-1-monthly-mean-ym_2005_01.nc
# 377    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output676/ocean/ocean-3d-u-1-monthly-pow02-ym_2005_01.nc
# 378     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output677/ocean/ocean-3d-u-1-monthly-mean-ym_2005_04.nc
# 379    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output677/ocean/ocean-3d-u-1-monthly-pow02-ym_2005_04.nc
# 380     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output678/ocean/ocean-3d-u-1-monthly-mean-ym_2005_07.nc
# 381    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output678/ocean/ocean-3d-u-1-monthly-pow02-ym_2005_07.nc
# 382     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output679/ocean/ocean-3d-u-1-monthly-mean-ym_2005_10.nc
# 383    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output679/ocean/ocean-3d-u-1-monthly-pow02-ym_2005_10.nc
# 384     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output680/ocean/ocean-3d-u-1-monthly-mean-ym_2006_01.nc
# 385    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output680/ocean/ocean-3d-u-1-monthly-pow02-ym_2006_01.nc
# 386     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output681/ocean/ocean-3d-u-1-monthly-mean-ym_2006_04.nc
# 387    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output681/ocean/ocean-3d-u-1-monthly-pow02-ym_2006_04.nc
# 388     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output682/ocean/ocean-3d-u-1-monthly-mean-ym_2006_07.nc
# 389    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output682/ocean/ocean-3d-u-1-monthly-pow02-ym_2006_07.nc
# 390     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output683/ocean/ocean-3d-u-1-monthly-mean-ym_2006_10.nc
# 391    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output683/ocean/ocean-3d-u-1-monthly-pow02-ym_2006_10.nc
# 392     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output684/ocean/ocean-3d-u-1-monthly-mean-ym_2007_01.nc
# 393    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output684/ocean/ocean-3d-u-1-monthly-pow02-ym_2007_01.nc
# 394     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output685/ocean/ocean-3d-u-1-monthly-mean-ym_2007_04.nc
# 395    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output685/ocean/ocean-3d-u-1-monthly-pow02-ym_2007_04.nc
# 396     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output686/ocean/ocean-3d-u-1-monthly-mean-ym_2007_07.nc
# 397    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output686/ocean/ocean-3d-u-1-monthly-pow02-ym_2007_07.nc
# 398     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output687/ocean/ocean-3d-u-1-monthly-mean-ym_2007_10.nc
# 399    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output687/ocean/ocean-3d-u-1-monthly-pow02-ym_2007_10.nc
# 400     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output688/ocean/ocean-3d-u-1-monthly-mean-ym_2008_01.nc
# 401    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output688/ocean/ocean-3d-u-1-monthly-pow02-ym_2008_01.nc
# 402     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output689/ocean/ocean-3d-u-1-monthly-mean-ym_2008_04.nc
# 403    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output689/ocean/ocean-3d-u-1-monthly-pow02-ym_2008_04.nc
# 404     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output690/ocean/ocean-3d-u-1-monthly-mean-ym_2008_07.nc
# 405    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output690/ocean/ocean-3d-u-1-monthly-pow02-ym_2008_07.nc
# 406     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output691/ocean/ocean-3d-u-1-monthly-mean-ym_2008_10.nc
# 407    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output691/ocean/ocean-3d-u-1-monthly-pow02-ym_2008_10.nc
# 408     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output692/ocean/ocean-3d-u-1-monthly-mean-ym_2009_01.nc
# 409    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output692/ocean/ocean-3d-u-1-monthly-pow02-ym_2009_01.nc
# 410     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output693/ocean/ocean-3d-u-1-monthly-mean-ym_2009_04.nc
# 411    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output693/ocean/ocean-3d-u-1-monthly-pow02-ym_2009_04.nc
# 412     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output694/ocean/ocean-3d-u-1-monthly-mean-ym_2009_07.nc
# 413    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output694/ocean/ocean-3d-u-1-monthly-pow02-ym_2009_07.nc
# 414     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output695/ocean/ocean-3d-u-1-monthly-mean-ym_2009_10.nc
# 415    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output695/ocean/ocean-3d-u-1-monthly-pow02-ym_2009_10.nc
# 416     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output696/ocean/ocean-3d-u-1-monthly-mean-ym_2010_01.nc
# 417    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output696/ocean/ocean-3d-u-1-monthly-pow02-ym_2010_01.nc
# 418     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output697/ocean/ocean-3d-u-1-monthly-mean-ym_2010_04.nc
# 419    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output697/ocean/ocean-3d-u-1-monthly-pow02-ym_2010_04.nc
# 420     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output698/ocean/ocean-3d-u-1-monthly-mean-ym_2010_07.nc
# 421    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output698/ocean/ocean-3d-u-1-monthly-pow02-ym_2010_07.nc
# 422     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output699/ocean/ocean-3d-u-1-monthly-mean-ym_2010_10.nc
# 423    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output699/ocean/ocean-3d-u-1-monthly-pow02-ym_2010_10.nc
# 424     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output700/ocean/ocean-3d-u-1-monthly-mean-ym_2011_01.nc
# 425    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output700/ocean/ocean-3d-u-1-monthly-pow02-ym_2011_01.nc
# 426     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output701/ocean/ocean-3d-u-1-monthly-mean-ym_2011_04.nc
# 427    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output701/ocean/ocean-3d-u-1-monthly-pow02-ym_2011_04.nc
# 428     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output702/ocean/ocean-3d-u-1-monthly-mean-ym_2011_07.nc
# 429    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output702/ocean/ocean-3d-u-1-monthly-pow02-ym_2011_07.nc
# 430     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output703/ocean/ocean-3d-u-1-monthly-mean-ym_2011_10.nc
# 431    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output703/ocean/ocean-3d-u-1-monthly-pow02-ym_2011_10.nc
# 432     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output704/ocean/ocean-3d-u-1-monthly-mean-ym_2012_01.nc
# 433    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output704/ocean/ocean-3d-u-1-monthly-pow02-ym_2012_01.nc
# 434     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output705/ocean/ocean-3d-u-1-monthly-mean-ym_2012_04.nc
# 435    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output705/ocean/ocean-3d-u-1-monthly-pow02-ym_2012_04.nc
# 436     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output706/ocean/ocean-3d-u-1-monthly-mean-ym_2012_07.nc
# 437    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output706/ocean/ocean-3d-u-1-monthly-pow02-ym_2012_07.nc
# 438     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output707/ocean/ocean-3d-u-1-monthly-mean-ym_2012_10.nc
# 439    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output707/ocean/ocean-3d-u-1-monthly-pow02-ym_2012_10.nc
# 440     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output708/ocean/ocean-3d-u-1-monthly-mean-ym_2013_01.nc
# 441    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output708/ocean/ocean-3d-u-1-monthly-pow02-ym_2013_01.nc
# 442     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output709/ocean/ocean-3d-u-1-monthly-mean-ym_2013_04.nc
# 443    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output709/ocean/ocean-3d-u-1-monthly-pow02-ym_2013_04.nc
# 444     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output710/ocean/ocean-3d-u-1-monthly-mean-ym_2013_07.nc
# 445    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output710/ocean/ocean-3d-u-1-monthly-pow02-ym_2013_07.nc
# 446     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output711/ocean/ocean-3d-u-1-monthly-mean-ym_2013_10.nc
# 447    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output711/ocean/ocean-3d-u-1-monthly-pow02-ym_2013_10.nc
# 448     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output712/ocean/ocean-3d-u-1-monthly-mean-ym_2014_01.nc
# 449    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output712/ocean/ocean-3d-u-1-monthly-pow02-ym_2014_01.nc
# 450     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output713/ocean/ocean-3d-u-1-monthly-mean-ym_2014_04.nc
# 451    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output713/ocean/ocean-3d-u-1-monthly-pow02-ym_2014_04.nc
# 452     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output714/ocean/ocean-3d-u-1-monthly-mean-ym_2014_07.nc
# 453    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output714/ocean/ocean-3d-u-1-monthly-pow02-ym_2014_07.nc
# 454     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output715/ocean/ocean-3d-u-1-monthly-mean-ym_2014_10.nc
# 455    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output715/ocean/ocean-3d-u-1-monthly-pow02-ym_2014_10.nc
# 456     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output716/ocean/ocean-3d-u-1-monthly-mean-ym_2015_01.nc
# 457    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output716/ocean/ocean-3d-u-1-monthly-pow02-ym_2015_01.nc
# 458     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output717/ocean/ocean-3d-u-1-monthly-mean-ym_2015_04.nc
# 459    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output717/ocean/ocean-3d-u-1-monthly-pow02-ym_2015_04.nc
# 460     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output718/ocean/ocean-3d-u-1-monthly-mean-ym_2015_07.nc
# 461    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output718/ocean/ocean-3d-u-1-monthly-pow02-ym_2015_07.nc
# 462     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output719/ocean/ocean-3d-u-1-monthly-mean-ym_2015_10.nc
# 463    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output719/ocean/ocean-3d-u-1-monthly-pow02-ym_2015_10.nc
# 464     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output720/ocean/ocean-3d-u-1-monthly-mean-ym_2016_01.nc
# 465    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output720/ocean/ocean-3d-u-1-monthly-pow02-ym_2016_01.nc
# 466     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output721/ocean/ocean-3d-u-1-monthly-mean-ym_2016_04.nc
# 467    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output721/ocean/ocean-3d-u-1-monthly-pow02-ym_2016_04.nc
# 468     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output722/ocean/ocean-3d-u-1-monthly-mean-ym_2016_07.nc
# 469    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output722/ocean/ocean-3d-u-1-monthly-pow02-ym_2016_07.nc
# 470     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output723/ocean/ocean-3d-u-1-monthly-mean-ym_2016_10.nc
# 471    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output723/ocean/ocean-3d-u-1-monthly-pow02-ym_2016_10.nc
# 472     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output724/ocean/ocean-3d-u-1-monthly-mean-ym_2017_01.nc
# 473    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output724/ocean/ocean-3d-u-1-monthly-pow02-ym_2017_01.nc
# 474     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output725/ocean/ocean-3d-u-1-monthly-mean-ym_2017_04.nc
# 475    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output725/ocean/ocean-3d-u-1-monthly-pow02-ym_2017_04.nc
# 476     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output726/ocean/ocean-3d-u-1-monthly-mean-ym_2017_07.nc
# 477    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output726/ocean/ocean-3d-u-1-monthly-pow02-ym_2017_07.nc
# 478     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output727/ocean/ocean-3d-u-1-monthly-mean-ym_2017_10.nc
# 479    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output727/ocean/ocean-3d-u-1-monthly-pow02-ym_2017_10.nc
# 480     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output728/ocean/ocean-3d-u-1-monthly-mean-ym_2018_01.nc
# 481    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output728/ocean/ocean-3d-u-1-monthly-pow02-ym_2018_01.nc
# 482     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output729/ocean/ocean-3d-u-1-monthly-mean-ym_2018_04.nc
# 483    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output729/ocean/ocean-3d-u-1-monthly-pow02-ym_2018_04.nc
# 484     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output730/ocean/ocean-3d-u-1-monthly-mean-ym_2018_07.nc
# 485    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output730/ocean/ocean-3d-u-1-monthly-pow02-ym_2018_07.nc
# 486     /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output731/ocean/ocean-3d-u-1-monthly-mean-ym_2018_10.nc
# 487    /g/data/cj50/access-om2/raw-output/access-om2-01/01deg_jra55v140_iaf_cycle3/output731/ocean/ocean-3d-u-1-monthly-pow02-ym_2018_10.nc
# Name: path, dtype: object

# %%
u_og = xr.open_mfdataset(
    df_mean["path"].tolist(),
    combine="by_coords",
    decode_times=True,
    decode_timedelta=True
)["u"]

# %%
##########################
hu_transect_list = []
hu_sliced_list = []
max_lat = []
southward_threshold = []
northward_threshold = []
temp_southward = []
temp_northward = []
rho_southward = []
rho_northward = []
u_southward = []
u_northward = []
yearinds = [[np.arange(10)*0],[np.arange(10)*0],[np.arange(10)*0]]
yearinds_S = [[np.arange(10)*0],[np.arange(10)*0],[np.arange(10)*0]]
longitude_slices_10dg = [-63.5,-133.5, -173.5]
for i in tqdm(range(longitude_slices.size)):
    print(i)
    # select out longitude:
    u_along_regional = U_along_annual_binned_CDW_volav_f3.U.sel(lon_bins=longitude_slices_10dg[i])
    
    # find u_along threshold for most southward 100 months:
    u_sorted = u_along_regional.sortby(u_along_regional)
    npoints = 10
    southward_threshold.append(u_sorted[npoints].data) #negative, westward threshold for ASC
    northward_threshold.append(u_sorted[-npoints].data) #Positive, eastward threshold for ASC

    ## NOTE: We are now averaging over ten longitude bins

    # import bathymetry:
    if i<2:
        hu_sliced = hu_transect_og.sel(xu_ocean=longitude_slices[i], method='nearest').sel(yu_ocean=lat_range)
        hu_transect = hu_transect_og.sel(xu_ocean=slice(longitude_slices[i]-5, longitude_slices[i]+5)).mean('xu_ocean').sel(yu_ocean=lat_range)
    else:
        hu_sliced = hu_transect_og.sel(xu_ocean=lon_transect_u, yu_ocean = lat_transect_u, method='nearest')

    # fill nans with zeros:
    hu_transect = hu_transect.where(hu_transect>0,0)
    hu_sliced = hu_sliced.where(hu_sliced>0,0)
    hu_transect_list.append(hu_transect)
    hu_sliced_list.append(hu_sliced)
    
    # find latitude limits for plot:
    # lats = (hu_transect.yu_ocean).where(hu_transect>0).compute()
    #min_lat = lats.dropna('yu_ocean').data[0]-.1
    #lats = (hu_transect.yu_ocean).where(hu_transect>3000).compute()
    if i<2:
        lats_2 = (hu_sliced.yu_ocean).where(hu_sliced>3000).compute()
        max_lat.append(lats_2.dropna('yu_ocean').data[0])
    else:
        max_lat.append(lat0)
    if i<2:
        # Use monthly data to pick southward times:
        temp = temp_og.sel(time=slice(start_time,end_time)).sel(xt_ocean=longitude_slices[i], method='nearest')\
                                                                           .sel(st_ocean=slice(0,1300)).sel(yt_ocean=lat_range)
        temp = temp.groupby('time.year').mean().load()
        
        temp_southward.append(temp.where(u_along_regional < southward_threshold[i]).mean('year').load())
        temp_northward.append(temp.where(u_along_regional > northward_threshold[i]).mean('year').load())
        yearinds[i] = u_along_regional.where(u_along_regional >= northward_threshold[i]).dropna(dim='year',how='all').year
        yearinds_S[i] = u_along_regional.where(u_along_regional <= southward_threshold[i]).dropna(dim='year',how='all').year
        
        rho = rho_og.sel(time=slice(start_time,end_time)).sel(xt_ocean=longitude_slices[i], method='nearest')\
                                                                           .sel(st_ocean=slice(0,1300)).sel(yt_ocean=lat_range)
        rho = rho.groupby('time.year').mean().load()
        
        rho_southward.append(rho.where(u_along_regional < southward_threshold[i]).mean('year').load())
        rho_northward.append(rho.where(u_along_regional > northward_threshold[i]).mean('year').load())
        
        u = u_og.sel(time=slice(start_time,end_time)).sel(xu_ocean=longitude_slices[i], method='nearest')\
                                                                           .sel(st_ocean=slice(0,1300)).sel(yu_ocean=lat_range)
        u = u.groupby('time.year').mean().load()
        
        u_southward.append(u.where(u_along_regional < southward_threshold[i]).mean('year').load())
        u_northward.append(u.where(u_along_regional > northward_threshold[i]).mean('year').load())
    else:
        temp = temp_og.sel(time=slice(start_time,end_time)).sel(xt_ocean=lon_transect_t, yt_ocean = lat_transect_t, method='nearest')\
                                                                   .sel(st_ocean=slice(0,1300))
        temp = temp.groupby('time.year').mean().load()
        temp_southward.append(temp.where(u_along_regional < southward_threshold[i]).mean('year').load())
        temp_northward.append(temp.where(u_along_regional > northward_threshold[i]).mean('year').load())
        yearinds[i] = u_along_regional.where(u_along_regional >= northward_threshold[i]).dropna(dim='year',how='all').year
        yearinds_S[i] = u_along_regional.where(u_along_regional <= southward_threshold[i]).dropna(dim='year',how='all').year

        rho = rho_og.sel(time=slice(start_time,end_time)).sel(xt_ocean=lon_transect_t, yt_ocean = lat_transect_t, method='nearest')\
                                                                           .sel(st_ocean=slice(0,1300))
        rho = rho.groupby('time.year').mean().load()
        
        rho_southward.append(rho.where(u_along_regional < southward_threshold[i]).mean('year').load())
        rho_northward.append(rho.where(u_along_regional > northward_threshold[i]).mean('year').load())
        
        u = u_og.sel(time=slice(start_time,end_time)).sel(xu_ocean=lon_transect_u, yu_ocean = lat_transect_u, method='nearest')\
                                                                           .sel(st_ocean=slice(0,1300))
        u = u.groupby('time.year').mean().load()
        
        u_southward.append(u.where(u_along_regional < southward_threshold[i]).mean('year').load())
        u_northward.append(u.where(u_along_regional > northward_threshold[i]).mean('year').load())
# Out:
#   0%|          | 0/3 [00:00<?, ?it/s]
# 0
#  33%|███▎      | 1/3 [01:04<02:08, 64.46s/it]
# 1
#  67%|██████▋   | 2/3 [02:08<01:04, 64.23s/it]
# 2
# 100%|██████████| 3/3 [02:41<00:00, 53.91s/it]

# %%
arr = np.linspace(-0.03, 0.01, 3)  # Generates 5 points
arr = arr[arr != 0]  # Remove zero
arr

u_levels = [[-.24,-.20,-.16,-.12,-.08,-.04,.04,.08,.12,.16,.20,.24],
            arr, arr]

# density_contours = [[1027.65,1027.78,1027.8],
#                     [1027.65,1027.78,1027.8,1027.82,1027.83],
#                     [1027.7,1027.78, 1027.82]]


density_contours = [[27.65,27.78,27.8],
                    [27.65,27.78,27.8,27.82,27.83],
                    [27.71,27.78, 27.82]]

# %%
# Function x**(1/2)
def forward(x):
    return x**(1/2)


def inverse(x):
    return x**2

# %%
mean_lon = (lon0+lon1)/2
longitude_slices_forname = longitude_slices.copy()
longitude_slices_forname[-1] = mean_lon

# %%
mindepth_plot=0.5
mindepth_plot_label=0
fontsize = 12
lat1_v2=-76.51
isobath_lat=[-62.94,-73.56,-75.2]
#velocity_levels =[-0.03,-0.02,-.01,0.08,0.12,0.16,0.20,0.24]

regions_selected = [ 'West Antarctic Peninsula','Getz', 'Glomar_angled']
regions_forname = [ 'West Antarctic Peninsula','Getz', 'Glomar']
longitude_slices_forname = longitude_slices.copy()
longitude_slices_forname[-1] = mean_lon
# Find indices where regions match those in regions_selected
inds_regions = np.where(np.isin(regions, regions_selected))[0]
min_lats_selected = [-63.51, -74.51, lat1_v2] #it was lat1 before
max_lats_selected = [-61.9, -72.9, -74.49]# Create a figure, the last instance was -73.2 before 
fig = plt.figure(figsize=(16*0.8, 9))

# Create a GridSpec for a 3x4 grid
grid = gs.GridSpec(nrows=3, ncols=3, figure=fig)
grid.update(hspace=0.3, wspace=0.25)  # Adjust vertical and horizontal spacing

# Initialize a list to store axes
axes = []

subplots = ['(a)', '(b)', '(c)', '(d)', '(e)', '(f)', '(g)', '(h)', '(i)']

# Loop through the 3x4 grid to create subplots
for j in range(inds_regions.size):  # Loop over rows
    ax1 = fig.add_subplot(grid[0, j])
    ax2 = fig.add_subplot(grid[1, j])
    ax3 = fig.add_subplot(grid[2, j])

    i = inds_regions[j]
    print(i)
    pcm = ax1.contourf(temp_northward[i].yt_ocean,temp_northward[i].st_ocean,
                       temp_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate'),
                       cmap = cmocean.thermal, norm = norm[i],levels=levels[i],extend='both') #norm = norm[i]
    #ax1.fill_between(temp_southward[i].yt_ocean,hu_transect_list[i],3000,zorder=3,color='darkgrey')
    ax1.fill_between(temp_southward[i].yt_ocean,hu_sliced_list[i],3000,zorder=3000,color='darkgrey')

    ax1.set_yscale('function', functions=(forward, inverse))
    ax1.set_ylim(1200,mindepth_plot)
    ax1.set_xlim(min_lats_selected[j],max_lats_selected[i])
    if j == 0:
        ax1.set_ylabel('Depth [m]',fontsize=fontsize)
        ax1.set_yticks([1200,800,400,100,mindepth_plot],labels=[1200,800,400,100,mindepth_plot_label])
    else:
        ax1.set_yticks([1200,800,400,100,mindepth_plot],labels=[])
    ax1.set_xticks([])
    ax1.set_title(str(regions_forname[i])+' ('+str(abs(longitude_slices_forname[i]))+' $^{\circ}$W'+')') #

    # colorbar:
    
    cont=ax1.contour(rho_northward[i].yt_ocean,rho_northward[i].st_ocean,
                     rho_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate')-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='-')
    #u_levels[i]
    cont2=ax1.contour(u_northward[i].yu_ocean.sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_northward[i].st_ocean,
                     u_northward[i].interpolate_na(dim='yu_ocean',method='nearest',fill_value='extrapolate').sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),\
                      [0.04,0.08,0.16,0.2,0.24] ,vmin=vmin_range[i],vmax=-vmin_range[i]*0.7,
                      cmap=cmocean.curl,zorder=2 ,fontsize=fontsize)
    ax1.set_xlim(min_lats_selected[j],max_lats_selected[i])
    ax1.clabel(cont2, inline=True, fontsize=9)
    
    cont2=ax1.pcolormesh(u_northward[i].yu_ocean,u_northward[i].st_ocean,
                     u_northward[i].interpolate_na(dim='yu_ocean',method='nearest',fill_value='extrapolate'),vmin=vmin_range[i],vmax=-vmin_range[i]*0.7,
                      cmap=cmocean.curl,zorder=0 )
    

    ax1.tick_params(labelsize=fontsize)
    ####################
        
    pcm = ax2.contourf(temp_southward[i].yt_ocean,temp_southward[i].st_ocean,
                       temp_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate'),
                       cmap = cmocean.thermal, norm = norm[i],levels=levels[i],extend='both')#norm = norm[i]
    # ax2.fill_between(temp_southward[i].yt_ocean,hu_transect_list[i],3000,zorder=3,color='darkgrey')
    ax2.fill_between(temp_southward[i].yt_ocean,hu_sliced_list[i],3000,zorder=3000,color='darkgrey')

    ax2.set_yscale('function', functions=(forward, inverse))
    ax2.set_ylim(1200,mindepth_plot)
    ax2.set_xlim(min_lats_selected[j],max_lats_selected[i])
    ax2.set_xticks([])
    print(min_lats_selected[j],max_lats_selected[i])

    if j == 0:
        ax2.set_ylabel('Depth [m]',fontsize=fontsize)
    # ax2.set_xlabel('Latitude',fontsize=fontsize)
    #ax2.set_xticks([-74,-73.5,-73,-72.5])
    #ax2.set_xticks([-66.5,-66,-65.5,-65])
        ax2.set_yticks([1200,800,400,100,mindepth_plot],labels=[1200,800,400,100,mindepth_plot_label])
    else:
        ax2.set_yticks([1200,800,400,100,mindepth_plot],labels=[])
    
    #ax2.set_title('u_aong westward (or less northward)',fontsize=fontsize)    
    
    cont=ax2.contour(rho_southward[i].yt_ocean,rho_southward[i].st_ocean,
                     rho_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate')-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='--')
    
    
    cont2=ax2.contour(u_southward[i].yu_ocean.sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_southward[i].st_ocean,
                     u_southward[i].interpolate_na(dim='yu_ocean',method='nearest',fill_value='extrapolate').sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_levels[i],vmin=vmin_range[i],vmax=-vmin_range[i]*0.7,
                      cmap=cmocean.curl,zorder=2 ,fontsize=fontsize)
    ax2.set_xlim(min_lats_selected[j],max_lats_selected[i])
    ax2.clabel(cont2, inline=True, fontsize=9)
    ax2.tick_params(labelsize=fontsize)
    #########

    pci = ax3.contourf(temp_southward[i].yt_ocean,temp_southward[i].st_ocean,
                   temp_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate')-\
                    temp_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate'),
                   cmap = cm.bwr,levels=np.linspace(-0.6,0.6,200), vmin=-0.6, vmax=0.6, extend='both',fontsize=fontsize)
    ax3.fill_between(temp_southward[i].yt_ocean,hu_sliced_list[i],3000,zorder=3000,color='darkgrey')

    ax3.set_yscale('function', functions=(forward, inverse))
    ax3.set_ylim(1200,mindepth_plot)
    ax3.set_xlim(min_lats_selected[j],max_lats_selected[i])
    if j == 0:
        ax3.set_ylabel('Depth [m]',fontsize=fontsize)
        ax3.set_yticks([1200,800,400,100,mindepth_plot],labels=[1200,800,400,100,mindepth_plot_label])
    else:
        ax3.set_yticks([1200,800,400,100,mindepth_plot],labels=[])

    ax3.set_xlabel('Latitude',fontsize=fontsize)
    print(ax3.get_xticks())
    xticklabels = abs(ax3.get_xticks())[1:-1]
    xticklabels_with_s = [f"{label:.1f}$^\circ$S" for label in xticklabels]  # Format as integers + 'S'
    print(xticklabels_with_s)
    ax3.set_xticks(ax3.get_xticks()[1:-1])
    ax3.set_xticklabels(xticklabels_with_s)

    ax3.tick_params(labelsize=fontsize)

    cont=ax3.contour(rho_northward[i].yt_ocean.sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i])),rho_northward[i].st_ocean,
                     rho_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate').sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i]))-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='-')
    #ax3.clabel(cont, inline=True, fontsize=9,inline_spacing=5,zorder=400)
    cont=ax3.contour(rho_southward[i].yt_ocean.sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i])),rho_southward[i].st_ocean,
                     rho_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate').sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i]))-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='--')

    ax1.text(-0.15,1, subplots[j], fontsize=fontsize, fontweight = 'bold', transform = ax1.transAxes, va = 'center', ha = 'center')
    ax2.text(-0.15,1, subplots[j+3], fontsize=fontsize, fontweight = 'bold', transform = ax2.transAxes, va = 'center', ha = 'center')
    ax3.text(-0.15,1, subplots[j+6], fontsize=fontsize, fontweight = 'bold', transform = ax3.transAxes, va = 'center', ha = 'center')
    # ax1.plot([-80,-50],[1000,1000]); ax1.plot([-62.94,-62.94],[1200,0])# finding the location of the isobath in the plot
    # ax2.plot([-80,-50],[1000,1000]); ax2.plot([-73.56,-73.56],[1200,0])# finding the location of the isobath in the plot
    # ax3.plot([-80,-50],[1000,1000]); ax3.plot([-75.2,-75.2],[1200,0])# finding the location of the isobath in the plot
    ax1.plot(isobath_lat[i], 0, marker='v', color='black', markersize=5,clip_on=False)
    ax1.plot(isobath_lat[i], 1250, marker='^', color='black', markersize=5,clip_on=False)
    ax2.plot(isobath_lat[i], 0, marker='v', color='black', markersize=5,clip_on=False)
    ax2.plot(isobath_lat[i], 1250, marker='^', color='black', markersize=5,clip_on=False)
    ax3.plot(isobath_lat[i], 0, marker='v', color='black', markersize=5,clip_on=False)
    ax3.plot(isobath_lat[i], 1250, marker='^', color='black', markersize=5,clip_on=False)

cax = fig.add_axes([0.93,0.43,0.012,0.43])
cbar = plt.colorbar(pcm, cax=cax,orientation = 'vertical',extend = 'neither',ticks=ticks[i])
cbar.set_label(r'Temperature [$^\circ$C]',fontsize=fontsize,labelpad=5)
cbar.ax.tick_params(labelsize=fontsize)

cax = fig.add_axes([0.93,0.095,0.012,0.25])
cbar = plt.colorbar(pci, cax=cax,orientation = 'vertical',extend = 'neither',ticks=[-.6,0,.6])
cbar.set_label(r'$\Delta T$ [$^\circ$C]',fontsize=fontsize,labelpad=5)
cbar.ax.tick_params(labelsize=fontsize)

# # colorbar:
# norm_cbar = plt.Normalize(vmin=-.24, vmax = 0.24)
# sm = plt.cm.ScalarMappable(cmap=cmocean.delta, norm = norm_cbar)

# cax = fig.add_axes([0.13,-0.04,0.2,0.022])
# cbar = plt.colorbar(sm, cax=cax,orientation = 'horizontal',extend = 'neither')
# cbar.set_label(r'Velocity Contour [m/s]',fontsize=fontsize,labelpad=5)
# cbar.ax.tick_params(labelsize=fontsize)
# cbar.ax.imshow(
#     np.ones((1, 256, 4)),  # White RGBA image
#     aspect='auto',
#     extent=[0, 1, 0, 1],
#     transform=cbar.ax.transAxes,
#     zorder=1,
#     cmap=matplotlib.colors.ListedColormap(['white'])
# )

# cmap = cmocean.delta         # Replace with your actual colormap

# for level in u_levels[0]:
#     x = norm_cbar(level)
#     color = cmap(x)
#     cbar.ax.vlines(x, 0, 1, color=color, linewidth=4, transform=cbar.ax.transAxes)

# colorbar:
# norm_cbar = plt.Normalize(vmin=-.03, vmax = 0.03)
# sm = plt.cm.ScalarMappable(cmap=cmocean.delta, norm = norm_cbar)

# cax = fig.add_axes([0.4,-0.04,0.5,0.022])
# cbar = plt.colorbar(sm, cax=cax,orientation = 'horizontal',extend = 'neither')
# cbar.set_label(r'Velocity Contour [m/s]',fontsize=fontsize,labelpad=5)
# cbar.ax.tick_params(labelsize=fontsize)
# cbar.ax.imshow(
#     np.ones((1, 256, 4)),  # White RGBA image
#     aspect='auto',
#     extent=[0, 1, 0, 1],
#     transform=cbar.ax.transAxes,
#     zorder=1,
#     cmap=matplotlib.colors.ListedColormap(['white'])
# )

# cmap = cmocean.delta         # Replace with your actual colormap

# for level in u_levels[1]:
#     x = norm_cbar(level)
#     color = cmap(x)
#     cbar.ax.vlines(x, 0, 1, color=color, linewidth=4, transform=cbar.ax.transAxes)

ax1.text(-2.9,0.5, 'Eastward ASC Anomaly', fontsize=fontsize, transform = ax1.transAxes, va = 'center', ha = 'center', rotation = 90)
ax2.text(-2.9,0.5, 'Westward ASC Anomaly', fontsize=fontsize, transform = ax2.transAxes, va = 'center', ha = 'center', rotation = 90)
ax3.text(-2.9,0.5, 'Eastward - westward', fontsize=fontsize, transform = ax3.transAxes, va = 'center', ha = 'center', rotation = 90)

# Adjust layout to avoid overlap
plt.tight_layout()
# figure_path = '/g/data/x77/wf4500/ASC_project/analysis_figs/selected_regions_transects_aug19_2025.png'
# plt.savefig(figure_path , dpi=300,bbox_inches='tight', pad_inches=0.1,facecolor='white')
# Show the plots
plt.show()
# Out:
# 0
# -63.51 -61.9
# [-64.  -63.5 -63.  -62.5 -62.  -61.5]
# ['63.5$^\\circ$S', '63.0$^\\circ$S', '62.5$^\\circ$S', '62.0$^\\circ$S']
# 1
# -74.51 -72.9
# [-75.  -74.5 -74.  -73.5 -73.  -72.5]
# ['74.5$^\\circ$S', '74.0$^\\circ$S', '73.5$^\\circ$S', '73.0$^\\circ$S']
# 2
# -76.51 -74.49
# [-77.  -76.5 -76.  -75.5 -75.  -74.5 -74. ]
# ['76.5$^\\circ$S', '76.0$^\\circ$S', '75.5$^\\circ$S', '75.0$^\\circ$S', '74.5$^\\circ$S']

# %% [markdown]
# Importing density layes definition of CDW

# %%
rho0_contour = xr.open_dataset('/g/data/x77/wf4500/ASC_project/Post_process/rho0_along_contour.nc')
potrho_edges  = np.append(np.append(1020,np.append(np.arange(1023,1027,.15),np.linspace(1027,rho0_contour.pot_rho_0.max().values+0.2,80))),1030)-1000

# %%
age_mask = xr.open_mfdataset('/g/data/v45/wf4500/ASC_project_files/**_age_mask.nc')
#potrho_edges = (np.array(age_mask.potrho0[:-1]) + np.array(age_mask.potrho0[1:]))/2
age_mask_shallow = age_mask.copy()
age_mask_shallow['potrho0'] = potrho_edges[:-1]
age_mask_deep = age_mask.copy()
age_mask_deep['potrho0'] = potrho_edges[1:]

# %%
#WAP CDW
mean_CDW_WAP_shallow= age_mask_shallow.CDW_mask.sel(lon_bins = -63.5).mean('time')
mean_CDW_WAP_deep= age_mask_deep.CDW_mask.sel(lon_bins = -63.5).mean('time')
mean_CDW_WAP_shallow = (mean_CDW_WAP_shallow.where(mean_CDW_WAP_shallow!=0)*0)+1
mean_CDW_WAP_deep= (mean_CDW_WAP_deep.where(mean_CDW_WAP_deep!=0)*0)+1
mean_CDW_WAP_rhomin= (mean_CDW_WAP_shallow  * mean_CDW_WAP_shallow .potrho0).min('potrho0').values
mean_CDW_WAP_rhomax= (mean_CDW_WAP_deep * mean_CDW_WAP_deep.potrho0).max('potrho0').values
mean_CDW_WAP_rhomin,mean_CDW_WAP_rhomax
# Out:
# (array(27.7728375), array(27.8457467))

# %% [markdown]
# ## West Antarctic Peninsula

# %%
#streching depths between 200m and 800 m
def forward(z):
    z = np.array(z)

    out = np.zeros_like(z, dtype=float)

    # regions
    shallow = z <= 200
    mid = (z > 200) & (z <= 800)
    deep = z > 800

    # scaling factors (tune these!)
    s1 = 0.5   # compress shallow
    s2 = 2.0   # stretch mid (KEY PART)
    s3 = 0.5   # compress deep

    out[shallow] = z[shallow] * s1
    out[mid] = 200*s1 + (z[mid] - 200) * s2
    out[deep] = 200*s1 + (800-200)*s2 + (z[deep] - 800) * s3

    return out


def inverse(y):
    y = np.array(y)

    out = np.zeros_like(y, dtype=float)

    s1 = 0.5
    s2 = 2.0
    s3 = 0.5

    y1 = 200*s1
    y2 = y1 + (800-200)*s2

    shallow = y <= y1
    mid = (y > y1) & (y <= y2)
    deep = y > y2

    out[shallow] = y[shallow] / s1
    out[mid] = 200 + (y[mid] - y1) / s2
    out[deep] = 800 + (y[deep] - y2) / s3

    return out

# %%
# #original density contours
# density_contours = [[27.65,27.78,27.8],
#                     [27.65,27.78,27.8,27.82,27.83],
#                     [27.71,27.78, 27.82]]

#CDW defined density contours
density_contours = [[mean_CDW_WAP_rhomin,(mean_CDW_WAP_rhomin+mean_CDW_WAP_rhomax)/2,np.floor(mean_CDW_WAP_rhomax*100)/100],
                    [27.65,27.78,27.8,27.82,27.83],
                    [27.71,27.78, 27.82]]

# %%
# mindepth_plot=100
# mindepth_plot_label=100
mindepth_plot=1
mindepth_plot_label=0
fontsize = 12
lat1_v2=-76.51
isobath_lat=[-62.94,-73.56,-75.2]
#velocity_levels =[-0.03,-0.02,-.01,0.08,0.12,0.16,0.20,0.24]

regions_selected = [ 'West Antarctic Peninsula','Getz', 'Glomar_angled']
regions_forname = [ 'West Antarctic Peninsula','Getz', 'Glomar']
longitude_slices_forname = longitude_slices.copy()
longitude_slices_forname[-1] = mean_lon
# Find indices where regions match those in regions_selected
inds_regions = np.where(np.isin(regions, regions_selected))[0]
min_lats_selected = [-63.51, -74.51, lat1_v2] #it was lat1 before
max_lats_selected = [-61.9, -72.9, -74.49]# Create a figure, the last instance was -73.2 before 

min_lats_selected[j] = -63.6
max_lats_selected[i] = -62.3

fig = plt.figure(figsize=(16, 9))

# Create a GridSpec for a 3x4 grid
grid = gs.GridSpec(nrows=3, ncols=3, figure=fig)
grid.update(hspace=0.3, wspace=0.6)  # Adjust vertical and horizontal spacing

# Initialize a list to store axes
axes = []

subplots = ['(a)', '(b)', '(d)', '(c)', '(g)', '(f)', '(e)', '(h)', '(i)']

# Loop through the 3x4 grid to create subplots
for j in range(1):  # Loop over rows inds_regions.size
    ax1 = fig.add_subplot(grid[0, j])
    ax2 = fig.add_subplot(grid[1, j])
    ax3 = fig.add_subplot(grid[2, j])

    i = inds_regions[j]
    print(i)
    pcm = ax1.contourf(temp_northward[i].yt_ocean,temp_northward[i].st_ocean,
                       temp_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate'),
                       cmap = cmocean.thermal, norm = norm[i],levels=levels[i],extend='both') #norm = norm[i]
    #ax1.fill_between(temp_southward[i].yt_ocean,hu_transect_list[i],3000,zorder=3,color='darkgrey')
    ax1.fill_between(temp_southward[i].yt_ocean,hu_sliced_list[i],3000,zorder=3000,color='darkgrey')

    ax1.set_yscale('function', functions=(forward, inverse))
    ax1.set_ylim(1200,mindepth_plot)
    ax1.set_xlim(min_lats_selected[j],max_lats_selected[i])
    if j == 0:
        ax1.set_ylabel('Depth [m]',fontsize=fontsize)
        ax1.set_yticks([1200,600,400,mindepth_plot],labels=[1200,600,400,mindepth_plot_label])
    else:
        ax1.set_yticks([1200,600,400,mindepth_plot],labels=[])
    ax1.set_xticks([])
    ax1.set_title(str(regions_forname[i])+' ('+str(abs(longitude_slices_forname[i]))+' $^{\circ}$W'+')')# \n r$^2$ interannual: '+str(r_sq_annual_10deg.sel(lon_bins=longitude_slices[i]).values.round(2))

    # colorbar:
    
    cont=ax1.contour(rho_northward[i].yt_ocean,rho_northward[i].st_ocean,
                     rho_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate')-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='-')
    
    cont2=ax1.contour(u_northward[i].yu_ocean.sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_northward[i].st_ocean,
                     u_northward[i].interpolate_na(dim='yu_ocean',method='nearest',fill_value='extrapolate').sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_levels[i],vmin=vmin_range[i],vmax=-vmin_range[i]*0.7,
                      cmap=cmocean.curl,zorder=2 ,fontsize=fontsize)
    # cont2=ax1.contour((u_northward[i].yu_ocean.sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_northward[i].st_ocean,u_northward[i].interpolate_na(dim='yu_ocean',method='nearest',fill_value='extrapolate').sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i]))\
    #                    ,levels=[0.04,0.08,0.16,0.2,0.24] ,vmin=vmin_range[i],vmax=-vmin_range[i]*0.7,cmap=cmocean.curl,zorder=2 ,fontsize=fontsize
    
    ax1.set_xlim(min_lats_selected[j],max_lats_selected[i])
    ax1.clabel(cont2, inline=True, fontsize=9)
    
    cont2=ax1.pcolormesh(u_northward[i].yu_ocean,u_northward[i].st_ocean,
                     u_northward[i].interpolate_na(dim='yu_ocean',method='nearest',fill_value='extrapolate'),vmin=vmin_range[i],vmax=-vmin_range[i]*0.7,
                      cmap=cmocean.curl,zorder=0 )
    

    ax1.tick_params(labelsize=fontsize)
    ####################
        
    pcm = ax2.contourf(temp_southward[i].yt_ocean,temp_southward[i].st_ocean,
                       temp_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate'),
                       cmap = cmocean.thermal, norm = norm[i],levels=levels[i],extend='both')#norm = norm[i]
    # ax2.fill_between(temp_southward[i].yt_ocean,hu_transect_list[i],3000,zorder=3,color='darkgrey')
    ax2.fill_between(temp_southward[i].yt_ocean,hu_sliced_list[i],3000,zorder=3000,color='darkgrey')

    ax2.set_yscale('function', functions=(forward, inverse))
    ax2.set_ylim(1200,mindepth_plot)
    ax2.set_xlim(min_lats_selected[j],max_lats_selected[i])
    ax2.set_xticks([])
    print(min_lats_selected[j],max_lats_selected[i])

    if j == 0:
        ax2.set_ylabel('Depth [m]',fontsize=fontsize)
    # ax2.set_xlabel('Latitude',fontsize=fontsize)
    #ax2.set_xticks([-74,-73.5,-73,-72.5])
    #ax2.set_xticks([-66.5,-66,-65.5,-65])
        ax2.set_yticks([1200,600,400,mindepth_plot],labels=[1200,600,400,mindepth_plot_label])
    else:
        ax2.set_yticks([1200,600,400,mindepth_plot],labels=[])
    
    #ax2.set_title('u_aong westward (or less northward)',fontsize=fontsize)    
    
    cont=ax2.contour(rho_southward[i].yt_ocean,rho_southward[i].st_ocean,
                     rho_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate')-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='--')
    
    [0.04,0.08,0.12,0.16,0.20,0.24]
    cont2=ax2.contour(u_southward[i].yu_ocean.sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_southward[i].st_ocean,
                     u_southward[i].interpolate_na(dim='yu_ocean',method='nearest',fill_value='extrapolate').sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),\
                      u_levels[i],vmin=vmin_range[i],vmax=-vmin_range[i]*0.7,
                      cmap=cmocean.curl,zorder=2 ,fontsize=fontsize)
    ax2.set_xlim(min_lats_selected[j],max_lats_selected[i])
    ax2.clabel(cont2, inline=True, fontsize=9)
    ax2.tick_params(labelsize=fontsize)
    #########

    pci = ax3.contourf(temp_southward[i].yt_ocean,temp_southward[i].st_ocean,
                   temp_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate')-\
                    temp_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate'),
                   cmap = cm.bwr,levels=np.linspace(-1.2,1.2,200), vmin=-1.2, vmax=1.2, extend='both',fontsize=fontsize)
    ax3.fill_between(temp_southward[i].yt_ocean,hu_sliced_list[i],3000,zorder=3000,color='darkgrey')

    ax3.set_yscale('function', functions=(forward, inverse))
    ax3.set_ylim(1200,mindepth_plot)
    ax3.set_xlim(min_lats_selected[j],max_lats_selected[i])
    if j == 0:
        ax3.set_ylabel('Depth [m]',fontsize=fontsize)
        ax3.set_yticks([1200,700,400,mindepth_plot],labels=[1200,700,400,mindepth_plot_label])
    else:
        ax3.set_yticks([1200,700,400,mindepth_plot],labels=[])

    #ax3.set_xticks(ticks=[-63.3,-63,-62.7])
    ax3.set_xlabel('Latitude',fontsize=fontsize)
    print(ax3.get_xticks()[::2])
    #xticklabels = abs(ax3.get_xticks())[1:-1]
    xticklabels = abs(ax3.get_xticks()[::2])
    xticklabels_with_s = [f"{label:.1f}$^\circ$S" for label in xticklabels]  # Format as integers + 'S'
    print(xticklabels_with_s)
    ax3.set_xticks(ax3.get_xticks()[::2])
    ax3.set_xticklabels(xticklabels_with_s)

    ax3.tick_params(labelsize=fontsize)

    cont=ax3.contour(rho_northward[i].yt_ocean.sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i])),rho_northward[i].st_ocean,
                     rho_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate').sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i]))-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='-')
    #ax3.clabel(cont, inline=True, fontsize=9,inline_spacing=5,zorder=400)
    cont=ax3.contour(rho_southward[i].yt_ocean.sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i])),rho_southward[i].st_ocean,
                     rho_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate').sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i]))-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='--')

    ax1.text(-0.15,1, subplots[j], fontsize=fontsize, fontweight = 'bold', transform = ax1.transAxes, va = 'center', ha = 'center')
    ax2.text(-0.15,1, subplots[j+3], fontsize=fontsize, fontweight = 'bold', transform = ax2.transAxes, va = 'center', ha = 'center')
    ax3.text(-0.15,1, subplots[j+6], fontsize=fontsize, fontweight = 'bold', transform = ax3.transAxes, va = 'center', ha = 'center')
    # ax1.plot([-80,-50],[1000,1000]); ax1.plot([-62.94,-62.94],[1200,0])# finding the location of the isobath in the plot
    # ax2.plot([-80,-50],[1000,1000]); ax2.plot([-73.56,-73.56],[1200,0])# finding the location of the isobath in the plot
    # ax3.plot([-80,-50],[1000,1000]); ax3.plot([-75.2,-75.2],[1200,0])# finding the location of the isobath in the plot
    ax1.plot(isobath_lat[i], 0, marker='v', color='black', markersize=5,clip_on=False)
    ax1.plot(isobath_lat[i], 1250, marker='^', color='black', markersize=5,clip_on=False)
    ax2.plot(isobath_lat[i], 0, marker='v', color='black', markersize=5,clip_on=False)
    ax2.plot(isobath_lat[i], 1250, marker='^', color='black', markersize=5,clip_on=False)
    ax3.plot(isobath_lat[i], 0, marker='v', color='black', markersize=5,clip_on=False)
    ax3.plot(isobath_lat[i], 1250, marker='^', color='black', markersize=5,clip_on=False)



    #########timeseries

    grid = gs.GridSpec(nrows=2, ncols=3, figure=fig)
    grid.update(hspace=0.3, wspace=0.9)
    i = inds_regions[j]
    
    ax333 = fig.add_subplot(grid[0, j+1])
    ax444 = fig.add_subplot(grid[1, j+1])
    ###################
    ax333.set_title(regions[i] + ' (' + str(-longitude_slices[i]-5) + '-' \
                  + str(-longitude_slices[i]+5) + '$\degree$W)',fontsize=16)

    ax333_HT=ax333.twinx()
    ax333.plot(U_along_annual_binned_CDW_volav.year,U_along_annual_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='ASC',linewidth=outlinethickness,zorder=0,color=ASC_color)
    x=U_along_annual_binned_CDW_volav.year
    y=(U_along_annual_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100)
    plotcolors_ASC_annual(ax333,x,y,(0.5*np.max(np.abs(y))).values,'PiYG_r')#np.max(np.abs(y)).values
    ax333.set_title('(b) Interannual timeseries', fontweight='bold')
    #ax333.plot(U_along_annual_binned_CDW_volav.year,U_along_annual_binned_DSW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='DSW',color='k')
    # ax333.plot([1956,2024],[0,0],\
    #          linestyle='--',color='tab:blue')
    ax333.set_ylim([minASC[j],maxASC[j]])
    
    ax333_HT.plot(U_along_annual_binned_CDW_volav.year,(CSHT_annual_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12),\
                label='CSHT',color=CSHT_color,linewidth=outlinethickness,zorder=0)
    x=U_along_annual_binned_CDW_volav.year
    y=(CSHT_annual_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12)
    plotcolors_CSHT_annual(ax333_HT,x,y,np.max(np.abs(y)).values,'Reds_r')
    # ax333_HT.plot([1956,2024],[0,0],\
    #          linestyle='--',color='tab:orange')
    ax333_HT.set_ylim([minPHT[j],maxPHT[j]])
    # ax333.set_ylim(u_along_lims[i])
    # ax333.set_yticks([-3,-2,-1,0,1,2,3],labels=[-3,-2,-1,0,1,2,3],fontsize=14,color='tab:blue')
    if j == 0:
        ax333.set_ylabel('ASC speed [cm/s]',fontsize=fontsize,color=ASC_color, fontweight = 'bold')
        ax333.yaxis.set_label_coords(-0.1, 0.75)
    # ax333_HT.set_ylim(CSHT_lims[i])
    # ax333_HT.set_yticks([-10,-5,0,5,10],labels=[-10,-5,0,5,10],fontsize=14,color='tab:orange')
    # if j == inds_regions.size-1:
    ax333_HT.set_ylabel('Offshore Heat Transport [TW]',fontsize=fontsize,color=CSHT_color, fontweight = 'bold')
    ax333_HT.yaxis.set_label_coords(1.2, 0.35)
    
    ax333.set_xticks(ticks=np.arange(1960,2021,20),labels=np.arange(1960,2021,20), fontsize=fontsize)
    ax333.grid(alpha = 0.5)
    ax333.set_xlim(1957,2020)
    ax333.set_xlabel('Year',fontsize=fontsize)
    ax333.tick_params(axis='y', colors=ASC_color,labelsize=fontsize)  # Left y-axis ticks and labels in blue
    ax333_HT.tick_params(axis='y', colors=CSHT_color,labelsize=fontsize) # Right y-axis ticks and labels in orange
    #ax333.plot([yearsinds[j],yearsinds[j]],[np.array(yearsinds[j])*0-30,np.array(yearsinds[j])*0+30],':',color='silver',zorder=0)

    if j == 0:
        ax333.set_yticks(ax333.get_yticks()[1::2])
        ax333_HT.set_yticks(ax333_HT.get_yticks()[::2])
    if j == 1:
        ax333.set_yticks(ax333.get_yticks()[::2])
        ax333_HT.set_yticks(ax333_HT.get_yticks()[::2])        
    if j == 2:
        ax333_HT.set_yticks(ax333_HT.get_yticks()[1::2])

    ax333.set_yticklabels(ax333.get_yticks(), weight='bold')
    ax333_HT.set_yticklabels(ax333_HT.get_yticks(), weight='bold')
    ax333.annotate( 'r$^{2}$ = ' + str(np.round(r_sq_annual_10deg.sel(lon_bins = longitude_slices[i]).values,2)), \
             (0.6,0.5), xycoords='axes fraction', fontsize = fontsize, fontweight = 'bold', zorder = 600)  
    ax333.set_yticks(ticks=yticks_ASC[j],labels=yticks_ASC[j])
    ax333_HT.set_yticks(ticks=yticks_PHT[j],labels=yticks_PHT[j])
    ################
    
    ax444_HT=ax444.twinx()
    ax444.annotate( 'r$^{2}$ = ' + str(np.round(r_sq_clim_daily.sel(lon_bins = longitude_slices[i]).values,2)), \
                 (0.6,0.5), xycoords='axes fraction', fontsize = fontsize, fontweight = 'bold', zorder = 600)    
    
    ax444.plot(U_along_clima_binned_CDW_volav.dayofyear,U_along_clima_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='ASC',linewidth=outlinethickness,zorder=0,color=ASC_color)
    #ax444.plot(U_along_clima_binned_CDW_volav.dayofyear,U_along_clima_binned_DSW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='DSW',color='k')
    x=U_along_clima_binned_CDW_volav.dayofyear
    y=(U_along_clima_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100)
    plotcolors_ASC_clima(ax444,x,y,(1.1*np.max(np.abs(y))).values,'PiYG_r')#np.max(np.abs(y)).values
    # ax444.plot([0,365],[0,0],\
    #          linestyle='--',color='tab:blue')
    ax444.set_ylim([minASC[3+j],maxASC[3+j]])
    ax444_HT.plot(U_along_clima_binned_CDW_volav.dayofyear,(CSHT_clima_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12),\
                label='CSHT',color=CSHT_color,linewidth=outlinethickness,zorder=0)
    x=U_along_clima_binned_CDW_volav.dayofyear
    y=(CSHT_clima_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12)
    plotcolors_CSHT_clima(ax444_HT,x,y,np.max(np.abs(y)).values,'Reds_r')
    # ax444_HT.plot([0,365],[0,0],\
    #          linestyle='--',color='tab:orange')
    ax444_HT.set_ylim([minPHT[3+j],maxPHT[3+j]])
    ax444.set_title('(d) Climatology timeseries', fontweight='bold')

    if j == 0:    
        ax444.set_ylabel('ASC speed [cm/s]',fontsize=fontsize,color=ASC_color, fontweight = 'bold')
        ax444.yaxis.set_label_coords(-0.1, 0.75)
 
    # if j == inds_regions.size-1:
    ax444_HT.set_ylabel('Offshore Heat Transport [TW]',fontsize=fontsize,color=CSHT_color, fontweight = 'bold')
    ax444_HT.yaxis.set_label_coords(1.2, 0.35)
    ax444.set_xlabel('Day of year',fontsize=fontsize)
    #ax444.set_xticks(ticks=np.arange(0,365,50),labels=np.arange(0,365,50),fontsize=fontsize)
    ax444_HT.set_xticks(ticks=[],labels=[])
    ax444.grid(alpha = 0.5)
    # Set tick colors
    ax444.tick_params(axis='y', colors=ASC_color,labelsize=fontsize) # Left y-axis ticks and labels in blue
    ax444_HT.tick_params(axis='y', colors=CSHT_color,labelsize=fontsize)  # Right y-axis ticks and labels in orange
    ax444_HT.set_xlim(0,360)
    ax444.set_xticks(ticks=seasonal_xticks)
    ax444.set_xticklabels(labels=seasonal_xlabels, fontsize=fontsize-2, rotation=60, ha='center')
    ax444.tick_params(axis='x',labelsize=fontsize-2, labelrotation=60)


    if j == 0:
        ax444_HT.set_yticks(ax444_HT.get_yticks()[:])
        ax444.set_yticks(ax444.get_yticks()[1::2])
    if j == 1:
        ax444.set_yticks(ax444.get_yticks()[1::2])
        ax444_HT.set_yticks(ax444_HT.get_yticks()[1::2])
    if j == 2:
        ax444.set_yticks(ax444.get_yticks()[::2])    
        ax444_HT.set_yticks(ax444_HT.get_yticks()[1::2])


    ax444.set_yticklabels(np.round(ax444.get_yticks(),1), weight='bold')
    ax444_HT.set_yticklabels(ax444_HT.get_yticks(), weight='bold')
    ax444.set_yticks(ticks=yticks_ASC[3+j],labels=yticks_ASC[3+j])
    ax444_HT.set_yticks(ticks=yticks_PHT[3+j],labels=yticks_PHT[3+j])




ax3.text(2,0.5, 'Interannual', fontsize=18, transform = ax3.transAxes, va = 'center', ha = 'center', rotation = 90)
ax4.text(2,0.5, 'Climatology', fontsize=18, transform = ax4.transAxes, va = 'center', ha = 'center', rotation = 90)





cax = fig.add_axes([0.32,0.43,0.012,0.43])
cbar = plt.colorbar(pcm, cax=cax,orientation = 'vertical',extend = 'neither',ticks=ticks[i])
cbar.set_label(r'Temperature [$^\circ$C]',fontsize=fontsize,labelpad=1)
cbar.ax.tick_params(labelsize=fontsize)

cax = fig.add_axes([0.32,0.095,0.012,0.25])
cbar = plt.colorbar(pci, cax=cax,orientation = 'vertical',extend = 'neither',ticks=[-1.2,-.6,0,.6,1.2])
cbar.set_label(r'$\Delta T$ [$^\circ$C]',fontsize=fontsize,labelpad=1)
cbar.ax.tick_params(labelsize=fontsize)


ax1.text(-.35,0.5, 'Eastward ASC Anomaly', fontsize=fontsize, transform = ax1.transAxes, va = 'center', ha = 'center', rotation = 90)
ax2.text(-.35,0.5, 'Westward ASC Anomaly', fontsize=fontsize, transform = ax2.transAxes, va = 'center', ha = 'center', rotation = 90)
ax3.text(-.35,0.5, 'Eastward - westward', fontsize=fontsize, transform = ax3.transAxes, va = 'center', ha = 'center', rotation = 90)

# Adjust layout to avoid overlap
plt.tight_layout()
figure_path = '/g/data/x77/wf4500/ASC_project/analysis_figs/WAP_2026.png'
plt.savefig(figure_path , dpi=300,bbox_inches='tight', pad_inches=0.1,facecolor='white')
# Show the plots
plt.show()
# Out:
# 0
# -63.6 -62.3
# [-63.6 -63.2 -62.8 -62.4]
# ['63.6$^\\circ$S', '63.2$^\\circ$S', '62.8$^\\circ$S', '62.4$^\\circ$S']

# %% [markdown]
# ## Getz

# %%
# #GETZ CDW
# mean_CDW_GETZ= age_mask.CDW_mask.sel(lon_bins = -133.5).mean('time')
# mean_CDW_GETZ = (mean_CDW_GETZ.where(mean_CDW_GETZ!=0)*0)+1
# mean_CDW_GETZ_rhomin= np.floor((mean_CDW_GETZ * mean_CDW_GETZ.potrho0).min('potrho0').values*100)/100
# mean_CDW_GETZ_rhomax= np.floor((mean_CDW_GETZ * mean_CDW_GETZ.potrho0).max('potrho0').values*100)/100
# mean_CDW_GETZ_rhomin,mean_CDW_GETZ_rhomax


# #GETZ CDW
mean_CDW_GETZ_shallow= age_mask_shallow.CDW_mask.sel(lon_bins = -133.5,method='nearest').mean('time')
#mean_CDW_GETZ_shallow= age_mask_shallow.CDW_mask.sel(lon_bins = -133.5).sel(time=age_mask_shallow['time'].dt.year.isin(yearsinds[1])).mean('time')
mean_CDW_GETZ_deep= age_mask_deep.CDW_mask.sel(lon_bins = -133.5,method='nearest').mean('time')
mean_CDW_GETZ_shallow = (mean_CDW_GETZ_shallow.where(mean_CDW_GETZ_shallow!=0)*0)+1
mean_CDW_GETZ_deep= (mean_CDW_GETZ_deep.where(mean_CDW_GETZ_deep!=0)*0)+1
mean_CDW_GETZ_rhomin= -.02+ np.floor((mean_CDW_GETZ_shallow  * mean_CDW_GETZ_shallow .potrho0).min('potrho0').values*100)/100
mean_CDW_GETZ_rhomax= np.floor((mean_CDW_GETZ_deep * mean_CDW_GETZ_deep.potrho0).max('potrho0').values*100)/100
mean_CDW_GETZ_rhomin,mean_CDW_GETZ_rhomax
# Out:
# (27.73, 27.83)

# %%
#CDW defined density contours
density_contours = [[mean_CDW_WAP_rhomin,(mean_CDW_WAP_rhomin+mean_CDW_WAP_rhomax)/2,mean_CDW_WAP_rhomax],
                    [mean_CDW_GETZ_rhomin,(mean_CDW_GETZ_rhomin+mean_CDW_GETZ_rhomax)/2,mean_CDW_GETZ_rhomax],
                    [27.71,27.78, 27.82]]

# %%
mindepth_plot=1
mindepth_plot_label=0
fontsize = 12
lat1_v2=-76.51
isobath_lat=[-62.94,-73.56,-75.2]
#velocity_levels =[-0.03,-0.02,-.01,0.08,0.12,0.16,0.20,0.24]

regions_selected = [ 'West Antarctic Peninsula','Getz', 'Glomar_angled']
regions_forname = [ 'West Antarctic Peninsula','Getz', 'Glomar']
longitude_slices_forname = longitude_slices.copy()
longitude_slices_forname[-1] = mean_lon
# Find indices where regions match those in regions_selected
inds_regions = np.where(np.isin(regions, regions_selected))[0]
min_lats_selected = [-63.51, -74.51, lat1_v2] #it was lat1 before
max_lats_selected = [-61.9, -72.9, -74.49]# Create a figure, the last instance was -73.2 before 
fig = plt.figure(figsize=(16, 9))

# Create a GridSpec for a 3x4 grid
grid = gs.GridSpec(nrows=3, ncols=3, figure=fig)
grid.update(hspace=0.3, wspace=0.7)  # Adjust vertical and horizontal spacing

# Initialize a list to store axes
axes = []

subplots = ['(b)', '(a)', '(d)', '(g)', '(c)', '(f)', '(h)', '(e)', '(i)']

# Loop through the 3x4 grid to create subplots
for j in range(1,2):  # Loop over rows inds_regions.size
    ax1 = fig.add_subplot(grid[0, j])
    ax2 = fig.add_subplot(grid[1, j])
    ax3 = fig.add_subplot(grid[2, j])

    i = inds_regions[j]
    print(i)
    pcm = ax1.contourf(temp_northward[i].yt_ocean,temp_northward[i].st_ocean,
                       temp_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate'),
                       cmap = cmocean.thermal, norm = norm[i],levels=levels[i],extend='both') #norm = norm[i]
    #ax1.fill_between(temp_southward[i].yt_ocean,hu_transect_list[i],3000,zorder=3,color='darkgrey')
    ax1.fill_between(temp_southward[i].yt_ocean,hu_sliced_list[i],3000,zorder=3000,color='darkgrey')

    ax1.set_yscale('function', functions=(forward, inverse))
    ax1.set_ylim(1200,mindepth_plot)
    ax1.set_xlim(min_lats_selected[j],max_lats_selected[i])

    ax1.set_ylabel('Depth [m]',fontsize=fontsize)
    ax1.set_yticks([1200,600,400,mindepth_plot],labels=[1200,600,400,mindepth_plot_label])
    # else:
    #     ax1.set_yticks([1200,800,400,100,mindepth_plot],labels=[])
    ax1.set_xticks([])
    ax1.set_title(str(regions_forname[i])+' ('+str(abs(longitude_slices_forname[i]))+' $^{\circ}$W'+')')# \n r$^2$ interannual: '+str(r_sq_annual_10deg.sel(lon_bins=longitude_slices[i]).values.round(2))

    # colorbar:
    
    cont=ax1.contour(rho_northward[i].yt_ocean,rho_northward[i].st_ocean,
                     rho_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate')-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='-')
    
    cont2=ax1.contour(u_northward[i].yu_ocean.sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_northward[i].st_ocean,
                     u_northward[i].interpolate_na(dim='yu_ocean',method='nearest',fill_value='extrapolate').sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_levels[i],vmin=vmin_range[i],vmax=-vmin_range[i]*0.7,
                      cmap=cmocean.curl,zorder=2 ,fontsize=fontsize)
    ax1.set_xlim(min_lats_selected[j],max_lats_selected[i])
    ax1.clabel(cont2, inline=True, fontsize=9)
    
    cont2=ax1.pcolormesh(u_northward[i].yu_ocean,u_northward[i].st_ocean,
                     u_northward[i].interpolate_na(dim='yu_ocean',method='nearest',fill_value='extrapolate'),vmin=vmin_range[i],vmax=-vmin_range[i]*0.7,
                      cmap=cmocean.curl,zorder=0 )
    

    ax1.tick_params(labelsize=fontsize)
    ####################
        
    pcm = ax2.contourf(temp_southward[i].yt_ocean,temp_southward[i].st_ocean,
                       temp_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate'),
                       cmap = cmocean.thermal, norm = norm[i],levels=levels[i],extend='both')#norm = norm[i]
    # ax2.fill_between(temp_southward[i].yt_ocean,hu_transect_list[i],3000,zorder=3,color='darkgrey')
    ax2.fill_between(temp_southward[i].yt_ocean,hu_sliced_list[i],3000,zorder=3000,color='darkgrey')

    ax2.set_yscale('function', functions=(forward, inverse))
    ax2.set_ylim(1200,mindepth_plot)
    ax2.set_xlim(min_lats_selected[j],max_lats_selected[i])
    ax2.set_xticks([])
    print(min_lats_selected[j],max_lats_selected[i])


    ax2.set_ylabel('Depth [m]',fontsize=fontsize)
    # ax2.set_xlabel('Latitude',fontsize=fontsize)
    #ax2.set_xticks([-74,-73.5,-73,-72.5])
    #ax2.set_xticks([-66.5,-66,-65.5,-65])
    ax2.set_yticks([1200,600,400,mindepth_plot],labels=[1200,600,400,mindepth_plot_label])
    # else:
    #     ax2.set_yticks([1200,800,400,100,mindepth_plot],labels=[])
    
    #ax2.set_title('u_aong westward (or less northward)',fontsize=fontsize)    
    
    cont=ax2.contour(rho_southward[i].yt_ocean,rho_southward[i].st_ocean,
                     rho_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate')-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='--')
    
    
    cont2=ax2.contour(u_southward[i].yu_ocean.sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_southward[i].st_ocean,
                     u_southward[i].interpolate_na(dim='yu_ocean',method='nearest',fill_value='extrapolate').sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_levels[i],vmin=vmin_range[i],vmax=-vmin_range[i]*0.7,
                      cmap=cmocean.curl,zorder=2 ,fontsize=fontsize)
    ax2.set_xlim(min_lats_selected[j],max_lats_selected[i])
    ax2.clabel(cont2, inline=True, fontsize=9)
    ax2.tick_params(labelsize=fontsize)
    #########

    pci = ax3.contourf(temp_southward[i].yt_ocean,temp_southward[i].st_ocean,
                   temp_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate')-\
                    temp_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate'),
                   cmap = cm.bwr,levels=np.linspace(-0.3,0.3,200), vmin=-0.3, vmax=0.3, extend='both',fontsize=fontsize)
    ax3.fill_between(temp_southward[i].yt_ocean,hu_sliced_list[i],3000,zorder=3000,color='darkgrey')

    ax3.set_yscale('function', functions=(forward, inverse))
    ax3.set_ylim(1200,mindepth_plot)
    ax3.set_xlim(min_lats_selected[j],max_lats_selected[i])
    # if j == 0:
    ax3.set_ylabel('Depth [m]',fontsize=fontsize)
    ax3.set_yticks([1200,600,400,mindepth_plot],labels=[1200,600,400,mindepth_plot_label])
    # else:
    #     ax3.set_yticks([1200,800,400,100,mindepth_plot],labels=[])

    ax3.set_xlabel('Latitude',fontsize=fontsize)
    print(ax3.get_xticks())
    xticklabels = abs(ax3.get_xticks())[1:-1]
    xticklabels_with_s = [f"{label:.1f}$^\circ$S" for label in xticklabels]  # Format as integers + 'S'
    print(xticklabels_with_s)
    ax3.set_xticks(ax3.get_xticks()[1:-1])
    ax3.set_xticklabels(xticklabels_with_s)

    ax3.tick_params(labelsize=fontsize)

    cont=ax3.contour(rho_northward[i].yt_ocean.sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i])),rho_northward[i].st_ocean,
                     rho_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate').sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i]))-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='-')
    #ax3.clabel(cont, inline=True, fontsize=9,inline_spacing=5,zorder=400)
    cont=ax3.contour(rho_southward[i].yt_ocean.sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i])),rho_southward[i].st_ocean,
                     rho_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate').sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i]))-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='--')

    ax1.text(-0.15,1, subplots[j], fontsize=fontsize, fontweight = 'bold', transform = ax1.transAxes, va = 'center', ha = 'center')
    ax2.text(-0.15,1, subplots[j+3], fontsize=fontsize, fontweight = 'bold', transform = ax2.transAxes, va = 'center', ha = 'center')
    ax3.text(-0.15,1, subplots[j+6], fontsize=fontsize, fontweight = 'bold', transform = ax3.transAxes, va = 'center', ha = 'center')
    # ax1.plot([-80,-50],[1000,1000]); ax1.plot([-62.94,-62.94],[1200,0])# finding the location of the isobath in the plot
    # ax2.plot([-80,-50],[1000,1000]); ax2.plot([-73.56,-73.56],[1200,0])# finding the location of the isobath in the plot
    # ax3.plot([-80,-50],[1000,1000]); ax3.plot([-75.2,-75.2],[1200,0])# finding the location of the isobath in the plot
    ax1.plot(isobath_lat[i], 0, marker='v', color='black', markersize=5,clip_on=False)
    ax1.plot(isobath_lat[i], 1250, marker='^', color='black', markersize=5,clip_on=False)
    ax2.plot(isobath_lat[i], 0, marker='v', color='black', markersize=5,clip_on=False)
    ax2.plot(isobath_lat[i], 1250, marker='^', color='black', markersize=5,clip_on=False)
    ax3.plot(isobath_lat[i], 0, marker='v', color='black', markersize=5,clip_on=False)
    ax3.plot(isobath_lat[i], 1250, marker='^', color='black', markersize=5,clip_on=False)



    #########timeseries

    grid = gs.GridSpec(nrows=2, ncols=3, figure=fig)
    grid.update(hspace=0.3, wspace=0.9)
    i = inds_regions[j]
    
    ax333 = fig.add_subplot(grid[0, j+1])
    ax444 = fig.add_subplot(grid[1, j+1])
    ###################
    ax333.set_title(regions[i] + ' (' + str(-longitude_slices[i]-5) + '-' \
                  + str(-longitude_slices[i]+5) + '$\degree$W)',fontsize=16)

    ax333_HT=ax333.twinx()
    ax333.plot(U_along_annual_binned_CDW_volav.year,U_along_annual_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='ASC',linewidth=outlinethickness,zorder=0,color=ASC_color)
    x=U_along_annual_binned_CDW_volav.year
    y=(U_along_annual_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100)
    plotcolors_ASC_annual(ax333,x,y,(0.5*np.max(np.abs(y))).values,'PiYG_r')#np.max(np.abs(y)).values
    ax333.set_title('(b) Interannual timeseries', fontweight='bold')
    #ax333.plot(U_along_annual_binned_CDW_volav.year,U_along_annual_binned_DSW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='DSW',color='k')
    # ax333.plot([1956,2024],[0,0],\
    #          linestyle='--',color='tab:blue')
    ax333.set_ylim([minASC[j],maxASC[j]])
    
    ax333_HT.plot(U_along_annual_binned_CDW_volav.year,(CSHT_annual_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12),\
                label='CSHT',color=CSHT_color,linewidth=outlinethickness,zorder=0)
    x=U_along_annual_binned_CDW_volav.year
    y=(CSHT_annual_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12)
    plotcolors_CSHT_annual(ax333_HT,x,y,np.max(np.abs(y)).values,'Reds_r')
    # ax333_HT.plot([1956,2024],[0,0],\
    #          linestyle='--',color='tab:orange')
    ax333_HT.set_ylim([minPHT[j],maxPHT[j]])
    # ax333.set_ylim(u_along_lims[i])
    # ax333.set_yticks([-3,-2,-1,0,1,2,3],labels=[-3,-2,-1,0,1,2,3],fontsize=14,color='tab:blue')

    ax333.set_ylabel('ASC speed [cm/s]',fontsize=fontsize,color=ASC_color, fontweight = 'bold')
    ax333.yaxis.set_label_coords(-0.1, 0.75)
    # ax333_HT.set_ylim(CSHT_lims[i])
    # ax333_HT.set_yticks([-10,-5,0,5,10],labels=[-10,-5,0,5,10],fontsize=14,color='tab:orange')
    # if j == inds_regions.size-1:
    ax333_HT.set_ylabel('Offshore Heat Transport [TW]',fontsize=fontsize,color=CSHT_color, fontweight = 'bold')
    ax333_HT.yaxis.set_label_coords(1.2, 0.35)
    
    ax333.set_xticks(ticks=np.arange(1960,2021,20),labels=np.arange(1960,2021,20), fontsize=fontsize)
    ax333.grid(alpha = 0.5)
    ax333.set_xlim(1957,2020)
    ax333.set_xlabel('Year',fontsize=fontsize)
    ax333.tick_params(axis='y', colors=ASC_color,labelsize=fontsize)  # Left y-axis ticks and labels in blue
    ax333_HT.tick_params(axis='y', colors=CSHT_color,labelsize=fontsize) # Right y-axis ticks and labels in orange
    #ax333.plot([yearsinds[j],yearsinds[j]],[np.array(yearsinds[j])*0-30,np.array(yearsinds[j])*0+30],':',color='silver',zorder=0)

    if j == 0:
        ax333.set_yticks(ax333.get_yticks()[1::2])
        ax333_HT.set_yticks(ax333_HT.get_yticks()[::2])
    if j == 1:
        ax333.set_yticks(ax333.get_yticks()[::2])
        ax333_HT.set_yticks(ax333_HT.get_yticks()[::2])        
    if j == 2:
        ax333_HT.set_yticks(ax333_HT.get_yticks()[1::2])

    ax333.set_yticklabels(ax333.get_yticks(), weight='bold')
    ax333_HT.set_yticklabels(ax333_HT.get_yticks(), weight='bold')
    ax333.annotate( 'r$^{2}$ = ' + str(np.round(r_sq_annual_10deg.sel(lon_bins = longitude_slices[i]).values,2)), \
             (0.6,0.5), xycoords='axes fraction', fontsize = fontsize, fontweight = 'bold', zorder = 600)  
    ax333.set_yticks(ticks=yticks_ASC[j],labels=yticks_ASC[j])
    ax333_HT.set_yticks(ticks=yticks_PHT[j],labels=yticks_PHT[j])
    ################
    
    ax444_HT=ax444.twinx()
    ax444.annotate( 'r$^{2}$ = ' + str(np.round(r_sq_clim_daily.sel(lon_bins = longitude_slices[i]).values,2)), \
                 (0.6,0.5), xycoords='axes fraction', fontsize = fontsize, fontweight = 'bold', zorder = 600)    
    
    ax444.plot(U_along_clima_binned_CDW_volav.dayofyear,U_along_clima_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='ASC',linewidth=outlinethickness,zorder=0,color=ASC_color)
    #ax444.plot(U_along_clima_binned_CDW_volav.dayofyear,U_along_clima_binned_DSW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='DSW',color='k')
    x=U_along_clima_binned_CDW_volav.dayofyear
    y=(U_along_clima_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100)
    plotcolors_ASC_clima(ax444,x,y,(1.1*np.max(np.abs(y))).values,'PiYG_r')#np.max(np.abs(y)).values
    # ax444.plot([0,365],[0,0],\
    #          linestyle='--',color='tab:blue')
    ax444.set_ylim([minASC[3+j],maxASC[3+j]])
    ax444_HT.plot(U_along_clima_binned_CDW_volav.dayofyear,(CSHT_clima_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12),\
                label='CSHT',color=CSHT_color,linewidth=outlinethickness,zorder=0)
    x=U_along_clima_binned_CDW_volav.dayofyear
    y=(CSHT_clima_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12)
    plotcolors_CSHT_clima(ax444_HT,x,y,np.max(np.abs(y)).values,'Reds_r')
    # ax444_HT.plot([0,365],[0,0],\
    #          linestyle='--',color='tab:orange')
    ax444_HT.set_ylim([minPHT[3+j],maxPHT[3+j]])
    ax444.set_title('(d) Climatology timeseries', fontweight='bold')


    ax444.set_ylabel('ASC speed [cm/s]',fontsize=fontsize,color=ASC_color, fontweight = 'bold')
    ax444.yaxis.set_label_coords(-0.1, 0.75)
 
    # if j == inds_regions.size-1:
    ax444_HT.set_ylabel('Offshore Heat Transport [TW]',fontsize=fontsize,color=CSHT_color, fontweight = 'bold')
    ax444_HT.yaxis.set_label_coords(1.2, 0.35)
    ax444.set_xlabel('Day of year',fontsize=fontsize)
    #ax444.set_xticks(ticks=np.arange(0,365,50),labels=np.arange(0,365,50),fontsize=fontsize)
    ax444_HT.set_xticks(ticks=[],labels=[])
    ax444.grid(alpha = 0.5)
    # Set tick colors
    ax444.tick_params(axis='y', colors=ASC_color,labelsize=fontsize) # Left y-axis ticks and labels in blue
    ax444_HT.tick_params(axis='y', colors=CSHT_color,labelsize=fontsize)  # Right y-axis ticks and labels in orange
    ax444_HT.set_xlim(0,360)
    ax444.set_xticks(ticks=seasonal_xticks)
    ax444.set_xticklabels(labels=seasonal_xlabels, fontsize=fontsize-2, rotation=60, ha='center')
    ax444.tick_params(axis='x',labelsize=fontsize-2, labelrotation=60)


    if j == 0:
        ax444_HT.set_yticks(ax444_HT.get_yticks()[:])
        ax444.set_yticks(ax444.get_yticks()[1::2])
    if j == 1:
        ax444.set_yticks(ax444.get_yticks()[1::2])
        ax444_HT.set_yticks(ax444_HT.get_yticks()[1::2])
    if j == 2:
        ax444.set_yticks(ax444.get_yticks()[::2])    
        ax444_HT.set_yticks(ax444_HT.get_yticks()[1::2])


    ax444.set_yticklabels(np.round(ax444.get_yticks(),1), weight='bold')
    ax444_HT.set_yticklabels(ax444_HT.get_yticks(), weight='bold')
    ax444.set_yticks(ticks=yticks_ASC[3+j],labels=yticks_ASC[3+j])
    ax444_HT.set_yticks(ticks=yticks_PHT[3+j],labels=yticks_PHT[3+j])




ax3.text(2,0.5, 'Interannual', fontsize=18, transform = ax3.transAxes, va = 'center', ha = 'center', rotation = 90)
ax4.text(2,0.5, 'Climatology', fontsize=18, transform = ax4.transAxes, va = 'center', ha = 'center', rotation = 90)





cax = fig.add_axes([0.62,0.43,0.012,0.43])
cbar = plt.colorbar(pcm, cax=cax,orientation = 'vertical',extend = 'neither',ticks=ticks[i])
cbar.set_label(r'Temperature [$^\circ$C]',fontsize=fontsize,labelpad=1)
cbar.ax.tick_params(labelsize=fontsize)

cax = fig.add_axes([0.62,0.095,0.012,0.25])
cbar = plt.colorbar(pci, cax=cax,orientation = 'vertical',extend = 'neither',ticks=[-.3,0,.3])
cbar.set_label(r'$\Delta T$ [$^\circ$C]',fontsize=fontsize,labelpad=1)
cbar.ax.tick_params(labelsize=fontsize)


ax1.text(-.4,0.5, 'Eastward ASC Anomaly', fontsize=fontsize, transform = ax1.transAxes, va = 'center', ha = 'center', rotation = 90)
ax2.text(-.4,0.5, 'Westward ASC Anomaly', fontsize=fontsize, transform = ax2.transAxes, va = 'center', ha = 'center', rotation = 90)
ax3.text(-.4,0.5, 'Eastward - westward', fontsize=fontsize, transform = ax3.transAxes, va = 'center', ha = 'center', rotation = 90)

# Adjust layout to avoid overlap
plt.tight_layout()
figure_path = '/g/data/x77/wf4500/ASC_project/analysis_figs/Getz_2026.png'
plt.savefig(figure_path , dpi=300,bbox_inches='tight', pad_inches=0.1,facecolor='white')
# Show the plots
plt.show()
# Out:
# 1
# -74.51 -72.9
# [-75.  -74.5 -74.  -73.5 -73.  -72.5]
# ['74.5$^\\circ$S', '74.0$^\\circ$S', '73.5$^\\circ$S', '73.0$^\\circ$S']

# %% [markdown]
# ## Glomar

# %% [markdown]
# I will used a stronger streching here to focus on the right layers

# %%
#streching depths between 200m and 800 m
def forward(z):
    z = np.array(z)

    out = np.zeros_like(z, dtype=float)

    # regions
    shallow = z <= 200
    mid = (z > 200) & (z <= 800)
    deep = z > 800

    # scaling factors (tune these!)
    s1 = 0.2   # compress shallow
    s2 = 3.0   # stretch mid (KEY PART)
    s3 = 0.5   # compress deep

    out[shallow] = z[shallow] * s1
    out[mid] = 200*s1 + (z[mid] - 200) * s2
    out[deep] = 200*s1 + (800-200)*s2 + (z[deep] - 800) * s3

    return out


def inverse(y):
    y = np.array(y)

    out = np.zeros_like(y, dtype=float)

    s1 = 0.2
    s2 = 3.0
    s3 = 0.5

    y1 = 200*s1
    y2 = y1 + (800-200)*s2

    shallow = y <= y1
    mid = (y > y1) & (y <= y2)
    deep = y > y2

    out[shallow] = y[shallow] / s1
    out[mid] = 200 + (y[mid] - y1) / s2
    out[deep] = 800 + (y[deep] - y2) / s3

    return out

# %%
# #GLOMAR CDW
# mean_CDW_GLOMAR= age_mask.CDW_mask.sel(lon_bins = -160,method='nearest').mean('time')
# mean_CDW_GLOMAR = (mean_CDW_GLOMAR.where(mean_CDW_GLOMAR!=0)*0)+1
# mean_CDW_GLOMAR_rhomin= np.floor((mean_CDW_GLOMAR * mean_CDW_GLOMAR.potrho0).min('potrho0').values*100)/100
# mean_CDW_GLOMAR_rhomax= np.floor((mean_CDW_GLOMAR * mean_CDW_GLOMAR.potrho0).max('potrho0').values*100)/100
# mean_CDW_GLOMAR_rhomin,mean_CDW_GLOMAR_rhomax


#GLOMAR CDW
mean_CDW_GLOMAR_shallow= age_mask_shallow.CDW_mask.sel(lon_bins = -160,method='nearest').mean('time')
mean_CDW_GLOMAR_deep= age_mask_deep.CDW_mask.sel(lon_bins = -160,method='nearest').mean('time')
mean_CDW_GLOMAR_shallow = (mean_CDW_GLOMAR_shallow.where(mean_CDW_GLOMAR_shallow!=0)*0)+1
mean_CDW_GLOMAR_deep= (mean_CDW_GLOMAR_deep.where(mean_CDW_GLOMAR_deep!=0)*0)+1
mean_CDW_GLOMAR_rhomin= np.floor((mean_CDW_GLOMAR_shallow  * mean_CDW_GLOMAR_shallow .potrho0).min('potrho0').values*100)/100
mean_CDW_GLOMAR_rhomax= np.floor((mean_CDW_GLOMAR_deep * mean_CDW_GLOMAR_deep.potrho0).max('potrho0').values*100)/100
mean_CDW_GLOMAR_rhomin,mean_CDW_GLOMAR_rhomax
# Out:
# (27.77, 27.83)

# %%
#CDW defined density contours
density_contours = [[mean_CDW_WAP_rhomin,(mean_CDW_WAP_rhomin+mean_CDW_WAP_rhomax)/2,mean_CDW_WAP_rhomax],
                    [mean_CDW_GETZ_rhomin,(mean_CDW_GETZ_rhomin+mean_CDW_GETZ_rhomax)/2,mean_CDW_GETZ_rhomax],
                    [mean_CDW_GLOMAR_rhomin,(mean_CDW_GLOMAR_rhomin+mean_CDW_GLOMAR_rhomax)/2,mean_CDW_GLOMAR_rhomax]]

# %%
mindepth_plot=1
mindepth_plot_label=0
fontsize = 12
lat1_v2=-75.8 # 76.51
isobath_lat=[-62.94,-73.56,-75.2]
#velocity_levels =[-0.03,-0.02,-.01,0.08,0.12,0.16,0.20,0.24]

regions_selected = [ 'West Antarctic Peninsula','Getz', 'Glomar_angled']
regions_forname = [ 'West Antarctic Peninsula','Getz', 'Glomar']
longitude_slices_forname = longitude_slices.copy()
longitude_slices_forname[-1] = mean_lon
# Find indices where regions match those in regions_selected
inds_regions = np.where(np.isin(regions, regions_selected))[0]
min_lats_selected = [-63.51, -74.51, lat1_v2] #it was lat1 before
max_lats_selected = [-61.9, -72.9, -74.49]# Create a figure, the last instance was -73.2 before 
fig = plt.figure(figsize=(16, 9))

# Create a GridSpec for a 3x4 grid
grid = gs.GridSpec(nrows=3, ncols=3, figure=fig)
grid.update(hspace=0.3, wspace=0.7)  # Adjust vertical and horizontal spacing

# Initialize a list to store axes
axes = []

subplots = ['(b)', '(d)', '(a)', '(g)', '(f)', '(c)', '(h)', '(i)', '(e)']

# Loop through the 3x4 grid to create subplots
for j in range(2,3):  # Loop over rows inds_regions.size
    ax1 = fig.add_subplot(grid[0, j-1])
    ax2 = fig.add_subplot(grid[1, j-1])
    ax3 = fig.add_subplot(grid[2, j-1])

    i = inds_regions[j]
    print(i)
    pcm = ax1.contourf(temp_northward[i].yt_ocean,temp_northward[i].st_ocean,
                       temp_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate'),
                       cmap = cmocean.thermal, norm = norm[i],levels=levels[i],extend='both') #norm = norm[i]
    #ax1.fill_between(temp_southward[i].yt_ocean,hu_transect_list[i],3000,zorder=3,color='darkgrey')
    ax1.fill_between(temp_southward[i].yt_ocean,hu_sliced_list[i],3000,zorder=3000,color='darkgrey')

    ax1.set_yscale('function', functions=(forward, inverse))
    ax1.set_ylim(1200,mindepth_plot)
    ax1.set_xlim(min_lats_selected[j],max_lats_selected[i])

    ax1.set_ylabel('Depth [m]',fontsize=fontsize)
    ax1.set_yticks([1200,600,400,mindepth_plot],labels=[1200,600,400,mindepth_plot_label])
    # else:
    #     ax1.set_yticks([1200,800,400,100,mindepth_plot],labels=[])
    ax1.set_xticks([])
    ax1.set_title(str(regions_forname[i])+' ('+str(abs(longitude_slices_forname[i]))+' $^{\circ}$W'+')')# \n r$^2$ interannual: '+str(r_sq_annual_10deg.sel(lon_bins=longitude_slices[i]).values.round(2))

    # colorbar:
    
    cont=ax1.contour(rho_northward[i].yt_ocean,rho_northward[i].st_ocean,
                     rho_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate')-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='-')
    
    cont2=ax1.contour(u_northward[i].yu_ocean.sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_northward[i].st_ocean,
                     u_northward[i].interpolate_na(dim='yu_ocean',method='nearest',fill_value='extrapolate').sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_levels[i],vmin=vmin_range[i],vmax=-vmin_range[i]*0.7,
                      cmap=cmocean.curl,zorder=2 ,fontsize=fontsize)
    ax1.set_xlim(min_lats_selected[j],max_lats_selected[i])
    ax1.clabel(cont2, inline=True, fontsize=9)
    
    cont2=ax1.pcolormesh(u_northward[i].yu_ocean,u_northward[i].st_ocean,
                     u_northward[i].interpolate_na(dim='yu_ocean',method='nearest',fill_value='extrapolate'),vmin=vmin_range[i],vmax=-vmin_range[i]*0.7,
                      cmap=cmocean.curl,zorder=0 )
    

    ax1.tick_params(labelsize=fontsize)
    ####################
        
    pcm = ax2.contourf(temp_southward[i].yt_ocean,temp_southward[i].st_ocean,
                       temp_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate'),
                       cmap = cmocean.thermal, norm = norm[i],levels=levels[i],extend='both')#norm = norm[i]
    # ax2.fill_between(temp_southward[i].yt_ocean,hu_transect_list[i],3000,zorder=3,color='darkgrey')
    ax2.fill_between(temp_southward[i].yt_ocean,hu_sliced_list[i],3000,zorder=3000,color='darkgrey')

    ax2.set_yscale('function', functions=(forward, inverse))
    ax2.set_ylim(1200,mindepth_plot)
    ax2.set_xlim(min_lats_selected[j],max_lats_selected[i])
    ax2.set_xticks([])
    print(min_lats_selected[j],max_lats_selected[i])


    ax2.set_ylabel('Depth [m]',fontsize=fontsize)
    # ax2.set_xlabel('Latitude',fontsize=fontsize)
    #ax2.set_xticks([-74,-73.5,-73,-72.5])
    #ax2.set_xticks([-66.5,-66,-65.5,-65])
    ax2.set_yticks([1200,600,400,mindepth_plot],labels=[1200,600,400,mindepth_plot_label])
    # else:
    #     ax2.set_yticks([1200,800,400,100,mindepth_plot],labels=[])
    
    #ax2.set_title('u_aong westward (or less northward)',fontsize=fontsize)    
    
    cont=ax2.contour(rho_southward[i].yt_ocean,rho_southward[i].st_ocean,
                     rho_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate')-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='--')
    
    
    cont2=ax2.contour(u_southward[i].yu_ocean.sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_southward[i].st_ocean,
                     u_southward[i].interpolate_na(dim='yu_ocean',method='nearest',fill_value='extrapolate').sel(yu_ocean=slice(min_lats_selected[j],max_lats_selected[i])),u_levels[i],vmin=vmin_range[i],vmax=-vmin_range[i]*0.7,
                      cmap=cmocean.curl,zorder=2 ,fontsize=fontsize)
    ax2.set_xlim(min_lats_selected[j],max_lats_selected[i])
    ax2.clabel(cont2, inline=True, fontsize=9)
    ax2.tick_params(labelsize=fontsize)
    #########

    pci = ax3.contourf(temp_southward[i].yt_ocean,temp_southward[i].st_ocean,
                   temp_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate')-\
                    temp_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate'),
                   cmap = cm.bwr,levels=np.linspace(-0.6,0.6,200), vmin=-0.6, vmax=0.6, extend='both',fontsize=fontsize)
    ax3.fill_between(temp_southward[i].yt_ocean,hu_sliced_list[i],3000,zorder=3000,color='darkgrey')

    ax3.set_yscale('function', functions=(forward, inverse))
    ax3.set_ylim(1200,mindepth_plot)
    ax3.set_xlim(min_lats_selected[j],max_lats_selected[i])
    # if j == 0:
    ax3.set_ylabel('Depth [m]',fontsize=fontsize)
    ax3.set_yticks([1200,600,400,mindepth_plot],labels=[1200,600,400,mindepth_plot_label])
    # else:
    #     ax3.set_yticks([1200,800,400,100,mindepth_plot],labels=[])

    ax3.set_xlabel('Latitude',fontsize=fontsize)
    print(ax3.get_xticks()[1::2][:-1])
    xticklabels = abs(ax3.get_xticks()[1::2][:-1])
    xticklabels_with_s = [f"{label:.1f}$^\circ$S" for label in xticklabels]  # Format as integers + 'S'
    print(xticklabels_with_s)
    ax3.set_xticks(ax3.get_xticks()[1::2][:-1])
    ax3.set_xticklabels(xticklabels_with_s)

    ax3.tick_params(labelsize=fontsize)

    cont=ax3.contour(rho_northward[i].yt_ocean.sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i])),rho_northward[i].st_ocean,
                     rho_northward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate').sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i]))-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='-')
    #ax3.clabel(cont, inline=True, fontsize=9,inline_spacing=5,zorder=400)
    cont=ax3.contour(rho_southward[i].yt_ocean.sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i])),rho_southward[i].st_ocean,
                     rho_southward[i].interpolate_na(dim='yt_ocean',method='nearest',fill_value='extrapolate').sel(yt_ocean=slice(min_lats_selected[j],max_lats_selected[i]))-1000,density_contours[i],
                      colors='k',zorder=2000 ,fontsize=fontsize,linestyles='--')

    ax1.text(-0.15,1, subplots[j], fontsize=fontsize, fontweight = 'bold', transform = ax1.transAxes, va = 'center', ha = 'center')
    ax2.text(-0.15,1, subplots[j+3], fontsize=fontsize, fontweight = 'bold', transform = ax2.transAxes, va = 'center', ha = 'center')
    ax3.text(-0.15,1, subplots[j+6], fontsize=fontsize, fontweight = 'bold', transform = ax3.transAxes, va = 'center', ha = 'center')
    # ax1.plot([-80,-50],[1000,1000]); ax1.plot([-62.94,-62.94],[1200,0])# finding the location of the isobath in the plot
    # ax2.plot([-80,-50],[1000,1000]); ax2.plot([-73.56,-73.56],[1200,0])# finding the location of the isobath in the plot
    # ax3.plot([-80,-50],[1000,1000]); ax3.plot([-75.2,-75.2],[1200,0])# finding the location of the isobath in the plot
    ax1.plot(isobath_lat[i], 0, marker='v', color='black', markersize=5,clip_on=False)
    ax1.plot(isobath_lat[i], 1250, marker='^', color='black', markersize=5,clip_on=False)
    ax2.plot(isobath_lat[i], 0, marker='v', color='black', markersize=5,clip_on=False)
    ax2.plot(isobath_lat[i], 1250, marker='^', color='black', markersize=5,clip_on=False)
    ax3.plot(isobath_lat[i], 0, marker='v', color='black', markersize=5,clip_on=False)
    ax3.plot(isobath_lat[i], 1250, marker='^', color='black', markersize=5,clip_on=False)



    #########timeseries

    grid = gs.GridSpec(nrows=2, ncols=3, figure=fig)
    grid.update(hspace=0.3, wspace=0.9)
    i = inds_regions[j]
    
    ax333 = fig.add_subplot(grid[0, j])
    ax444 = fig.add_subplot(grid[1, j])
    ###################
    ax333.set_title(regions[i] + ' (' + str(-longitude_slices[i]-5) + '-' \
                  + str(-longitude_slices[i]+5) + '$\degree$W)',fontsize=16)

    ax333_HT=ax333.twinx()
    ax333.plot(U_along_annual_binned_CDW_volav.year,U_along_annual_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='ASC',linewidth=outlinethickness,zorder=0,color=ASC_color)
    x=U_along_annual_binned_CDW_volav.year
    y=(U_along_annual_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100)
    plotcolors_ASC_annual(ax333,x,y,(0.5*np.max(np.abs(y))).values,'PiYG_r')#np.max(np.abs(y)).values
    ax333.set_title('(b) Interannual timeseries', fontweight='bold')
    #ax333.plot(U_along_annual_binned_CDW_volav.year,U_along_annual_binned_DSW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='DSW',color='k')
    # ax333.plot([1956,2024],[0,0],\
    #          linestyle='--',color='tab:blue')
    ax333.set_ylim([minASC[j],maxASC[j]])
    
    ax333_HT.plot(U_along_annual_binned_CDW_volav.year,(CSHT_annual_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12),\
                label='CSHT',color=CSHT_color,linewidth=outlinethickness,zorder=0)
    x=U_along_annual_binned_CDW_volav.year
    y=(CSHT_annual_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12)
    plotcolors_CSHT_annual(ax333_HT,x,y,np.max(np.abs(y)).values,'Reds_r')
    # ax333_HT.plot([1956,2024],[0,0],\
    #          linestyle='--',color='tab:orange')
    ax333_HT.set_ylim([minPHT[j],maxPHT[j]])
    # ax333.set_ylim(u_along_lims[i])
    # ax333.set_yticks([-3,-2,-1,0,1,2,3],labels=[-3,-2,-1,0,1,2,3],fontsize=14,color='tab:blue')

    ax333.set_ylabel('ASC speed [cm/s]',fontsize=fontsize,color=ASC_color, fontweight = 'bold')
    ax333.yaxis.set_label_coords(-0.1, 0.75)
    # ax333_HT.set_ylim(CSHT_lims[i])
    # ax333_HT.set_yticks([-10,-5,0,5,10],labels=[-10,-5,0,5,10],fontsize=14,color='tab:orange')
    # if j == inds_regions.size-1:
    ax333_HT.set_ylabel('Offshore Heat Transport [TW]',fontsize=fontsize,color=CSHT_color, fontweight = 'bold')
    ax333_HT.yaxis.set_label_coords(1.2, 0.35)
    
    ax333.set_xticks(ticks=np.arange(1960,2021,20),labels=np.arange(1960,2021,20), fontsize=fontsize)
    ax333.grid(alpha = 0.5)
    ax333.set_xlim(1957,2020)
    ax333.set_xlabel('Year',fontsize=fontsize)
    ax333.tick_params(axis='y', colors=ASC_color,labelsize=fontsize)  # Left y-axis ticks and labels in blue
    ax333_HT.tick_params(axis='y', colors=CSHT_color,labelsize=fontsize) # Right y-axis ticks and labels in orange
    #ax333.plot([yearsinds[j],yearsinds[j]],[np.array(yearsinds[j])*0-30,np.array(yearsinds[j])*0+30],':',color='silver',zorder=0)

    if j == 0:
        ax333.set_yticks(ax333.get_yticks()[1::2])
        ax333_HT.set_yticks(ax333_HT.get_yticks()[::2])
    if j == 1:
        ax333.set_yticks(ax333.get_yticks()[::2])
        ax333_HT.set_yticks(ax333_HT.get_yticks()[::2])        
    if j == 2:
        ax333_HT.set_yticks(ax333_HT.get_yticks()[1::2])

    ax333.set_yticklabels(ax333.get_yticks(), weight='bold')
    ax333_HT.set_yticklabels(ax333_HT.get_yticks(), weight='bold')
    ax333.annotate( 'r$^{2}$ = ' + str(np.round(r_sq_annual_10deg.sel(lon_bins = longitude_slices[i]).values,2)), \
             (0.6,0.5), xycoords='axes fraction', fontsize = fontsize, fontweight = 'bold', zorder = 600)  
    ax333.set_yticks(ticks=yticks_ASC[j],labels=yticks_ASC[j])
    ax333_HT.set_yticks(ticks=yticks_PHT[j],labels=yticks_PHT[j])
    ################
    
    ax444_HT=ax444.twinx()
    ax444.annotate( 'r$^{2}$ = ' + str(np.round(r_sq_clim_daily.sel(lon_bins = longitude_slices[i]).values,2)), \
                 (0.6,0.5), xycoords='axes fraction', fontsize = fontsize, fontweight = 'bold', zorder = 600)    
    
    ax444.plot(U_along_clima_binned_CDW_volav.dayofyear,U_along_clima_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='ASC',linewidth=outlinethickness,zorder=0,color=ASC_color)
    #ax444.plot(U_along_clima_binned_CDW_volav.dayofyear,U_along_clima_binned_DSW_volav.U.sel(lon_bins=longitude_slices[i])*100,label='DSW',color='k')
    x=U_along_clima_binned_CDW_volav.dayofyear
    y=(U_along_clima_binned_CDW_volav.U.sel(lon_bins=longitude_slices[i])*100)
    plotcolors_ASC_clima(ax444,x,y,(1.1*np.max(np.abs(y))).values,'PiYG_r')#np.max(np.abs(y)).values
    # ax444.plot([0,365],[0,0],\
    #          linestyle='--',color='tab:blue')
    ax444.set_ylim([minASC[3+j],maxASC[3+j]])
    ax444_HT.plot(U_along_clima_binned_CDW_volav.dayofyear,(CSHT_clima_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12),\
                label='CSHT',color=CSHT_color,linewidth=outlinethickness,zorder=0)
    x=U_along_clima_binned_CDW_volav.dayofyear
    y=(CSHT_clima_binned_CDW.CSHT_ZC_lon_binned.sel(lon_bins=longitude_slices[i])/1e12)
    plotcolors_CSHT_clima(ax444_HT,x,y,np.max(np.abs(y)).values,'Reds_r')
    # ax444_HT.plot([0,365],[0,0],\
    #          linestyle='--',color='tab:orange')
    ax444_HT.set_ylim([minPHT[3+j],maxPHT[3+j]])
    ax444.set_title('(d) Climatology timeseries', fontweight='bold')


    ax444.set_ylabel('ASC speed [cm/s]\n',fontsize=fontsize,color=ASC_color, fontweight = 'bold')
    ax444.yaxis.set_label_coords(-0.1, 0.75)
 
    # if j == inds_regions.size-1:
    ax444_HT.set_ylabel('Offshore Heat Transport [TW]',fontsize=fontsize,color=CSHT_color, fontweight = 'bold')
    ax444_HT.yaxis.set_label_coords(1.2, 0.35)
    ax444.set_xlabel('Day of year',fontsize=fontsize)
    #ax444.set_xticks(ticks=np.arange(0,365,50),labels=np.arange(0,365,50),fontsize=fontsize)
    ax444_HT.set_xticks(ticks=[],labels=[])
    ax444.grid(alpha = 0.5)
    # Set tick colors
    ax444.tick_params(axis='y', colors=ASC_color,labelsize=fontsize) # Left y-axis ticks and labels in blue
    ax444_HT.tick_params(axis='y', colors=CSHT_color,labelsize=fontsize)  # Right y-axis ticks and labels in orange
    ax444_HT.set_xlim(0,360)
    ax444.set_xticks(ticks=seasonal_xticks)
    ax444.set_xticklabels(labels=seasonal_xlabels, fontsize=fontsize-2, rotation=60, ha='center')
    ax444.tick_params(axis='x',labelsize=fontsize-2, labelrotation=60)


    if j == 0:
        ax444_HT.set_yticks(ax444_HT.get_yticks()[:])
        ax444.set_yticks(ax444.get_yticks()[1::2])
    if j == 1:
        ax444.set_yticks(ax444.get_yticks()[1::2])
        ax444_HT.set_yticks(ax444_HT.get_yticks()[1::2])
    if j == 2:
        ax444.set_yticks(ax444.get_yticks()[::2])    
        ax444_HT.set_yticks(ax444_HT.get_yticks()[1::2])


    ax444.set_yticklabels(np.round(ax444.get_yticks(),1), weight='bold')
    ax444_HT.set_yticklabels(ax444_HT.get_yticks(), weight='bold')
    ax444.set_yticks(ticks=yticks_ASC[3+j],labels=yticks_ASC[3+j])
    ax444_HT.set_yticks(ticks=yticks_PHT[3+j],labels=yticks_PHT[3+j])




ax3.text(2,0.5, 'Interannual', fontsize=18, transform = ax3.transAxes, va = 'center', ha = 'center', rotation = 90)
ax4.text(2,0.5, 'Climatology', fontsize=18, transform = ax4.transAxes, va = 'center', ha = 'center', rotation = 90)





cax = fig.add_axes([0.62,0.43,0.012,0.43])
cbar = plt.colorbar(pcm, cax=cax,orientation = 'vertical',extend = 'neither',ticks=ticks[i])
cbar.set_label(r'Temperature [$^\circ$C]',fontsize=fontsize,labelpad=1)
cbar.ax.tick_params(labelsize=fontsize)

cax = fig.add_axes([0.62,0.095,0.012,0.25])
cbar = plt.colorbar(pci, cax=cax,orientation = 'vertical',extend = 'neither',ticks=[-.6,0,.6])
cbar.set_label(r'$\Delta T$ [$^\circ$C]',fontsize=fontsize,labelpad=1)
cbar.ax.tick_params(labelsize=fontsize)


ax1.text(-.4,0.5, 'Eastward ASC Anomaly', fontsize=fontsize, transform = ax1.transAxes, va = 'center', ha = 'center', rotation = 90)
ax2.text(-.4,0.5, 'Westward ASC Anomaly', fontsize=fontsize, transform = ax2.transAxes, va = 'center', ha = 'center', rotation = 90)
ax3.text(-.4,0.5, 'Eastward - westward', fontsize=fontsize, transform = ax3.transAxes, va = 'center', ha = 'center', rotation = 90)

# Adjust layout to avoid overlap
plt.tight_layout()
figure_path = '/g/data/x77/wf4500/ASC_project/analysis_figs/Glomar_2026.png'
plt.savefig(figure_path , dpi=300,bbox_inches='tight', pad_inches=0.1,facecolor='white')
# Show the plots
plt.show()
# Out:
# 2
# -75.8 -74.49
# [-75.75 -75.25 -74.75]
# ['75.8$^\\circ$S', '75.2$^\\circ$S', '74.8$^\\circ$S']
